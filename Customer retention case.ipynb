# %%
import pandas as pd
import numpy as np
import sklearn 
import seaborn as sns
import matplotlib.pyplot as plt

# %%
ds=pd.read_excel(r'C:\Users\DELL\Downloads\Customer_retention_dataset\customer_retention_dataset.xlsx')

# %%
ds
# Out:
#     1Gender of respondent 2 How old are you?   \
# 0                    Male         31-40 years
# 1                  Female         21-30 years
# 2                  Female         21-30 years
# 3                    Male         21-30 years
# 4                  Female         21-30 years
# ..                    ...                 ...
# 264                Female         21-30 years
# 265                Female         31-40 years
# 266                Female         41-50 yaers
# 267                Female  Less than 20 years
# 268                Female         41-50 yaers
#
#     3 Which city do you shop online from?  \
# 0                                   Delhi
# 1                                   Delhi
# 2                           Greater Noida
# 3                                 Karnal
# 4                              Bangalore
# ..                                    ...
# 264                                 Solan
# 265                             Ghaziabad
# ...

# %%
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 269 entries, 0 to 268
# Data columns (total 71 columns):
#  #   Column                                                                                                                                                                                                          Non-Null Count  Dtype
# ---  ------                                                                                                                                                                                                          --------------  -----
#  0   1Gender of respondent                                                                                                                                                                                           269 non-null    object
# ...

# %%
ds.keys()
# Out:
# Index(['1Gender of respondent', '2 How old are you? ',
#        '3 Which city do you shop online from?',
#        '4 What is the Pin Code of where you shop online from?',
#        '5 Since How Long You are Shopping Online ?',
#        '6 How many times you have made an online purchase in the past 1 year?',
#        '7 How do you access the internet while shopping on-line?',
#        '8 Which device do you use to access the online shopping?',
#        '9 What is the screen size of your mobile device?\t\t\t\t\t\t                                        ',
#        '10 What is the operating system (OS) of your device?\t\t\t\t                                          ',
#        '11 What browser do you run on your device to access the website?\t\t\t                                                          ',
#        '12 Which channel did you follow to arrive at your favorite online store for the first time?                                                                   ',
# ...

# %%
ds.shape
# Out:
# (269, 71)

# %%
ds.columns
# Out:
# Index(['1Gender of respondent', '2 How old are you? ',
#        '3 Which city do you shop online from?',
#        '4 What is the Pin Code of where you shop online from?',
#        '5 Since How Long You are Shopping Online ?',
#        '6 How many times you have made an online purchase in the past 1 year?',
#        '7 How do you access the internet while shopping on-line?',
#        '8 Which device do you use to access the online shopping?',
#        '9 What is the screen size of your mobile device?\t\t\t\t\t\t                                        ',
#        '10 What is the operating system (OS) of your device?\t\t\t\t                                          ',
#        '11 What browser do you run on your device to access the website?\t\t\t                                                          ',
#        '12 Which channel did you follow to arrive at your favorite online store for the first time?                                                                   ',
# ...

# %%
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 269 entries, 0 to 268
# Data columns (total 71 columns):
#  #   Column                                                                                                                                                                                                          Non-Null Count  Dtype
# ---  ------                                                                                                                                                                                                          --------------  -----
#  0   1Gender of respondent                                                                                                                                                                                           269 non-null    object
# ...

# %%
ds.isnull().sum()
# Out:
# 1Gender of respondent                                                   0
# 2 How old are you?                                                      0
# 3 Which city do you shop online from?                                   0
# 4 What is the Pin Code of where you shop online from?                   0
# 5 Since How Long You are Shopping Online ?                              0
#                                                                        ..
# Longer delivery period                                                  0
# Change in website/Application design                                    0
# Frequent disruption when moving from one page to another                0
# Website is as efficient as before                                       0
# Which of the Indian online retailer would you recommend to a friend?    0
# Length: 71, dtype: int64

# %%
#as we can see here that there is no null values ,so no need to treat with null values in this dataset

# %%
sns.heatmap(ds.isnull())
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 9 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\DELL\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 9 missing from current font.
#   font.set_text(s, 0, flags=flags)
# <AxesSubplot:>

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
ds["1Gender of respondent"]=le.fit_transform(ds["1Gender of respondent"])

# %%
ds["3 Which city do you shop online from?"]=le.fit_transform(ds["3 Which city do you shop online from?"])

# %%
ds["4 What is the Pin Code of where you shop online from?"]=le.fit_transform(ds["4 What is the Pin Code of where you shop online from?"])

# %%
ds["5 Since How Long You are Shopping Online ?"]=le.fit_transform(ds["5 Since How Long You are Shopping Online ?"])

# %%
ds["6 How many times you have made an online purchase in the past 1 year?"]=le.fit_transform(ds["6 How many times you have made an online purchase in the past 1 year?"])

# %%
ds["7 How do you access the internet while shopping on-line?"]=le.fit_transform(ds["7 How do you access the internet while shopping on-line?"])

# %%
ds["8 Which device do you use to access the online shopping?"]=le.fit_transform(ds["8 Which device do you use to access the online shopping?"])

# %%
ds["2 How old are you? "]=le.fit_transform(ds["2 How old are you? "])

# %%
ds["Longer time to get logged in (promotion, sales period)"]=le.fit_transform(ds["Longer time to get logged in (promotion, sales period)"])

# %%
ds
# Out:
#      1Gender of respondent  2 How old are you?   \
# 0                        1                    1
# 1                        0                    0
# 2                        0                    0
# 3                        1                    0
# 4                        0                    0
# ..                     ...                  ...
# 264                      0                    0
# 265                      0                    1
# 266                      0                    2
# 267                      0                    4
# 268                      0                    2
#
#      3 Which city do you shop online from?  \
# 0                                        2
# 1                                        2
# 2                                        4
# 3                                        6
# 4                                        0
# ..                                     ...
# 264                                     10
# ...

# %%
#here we do some analyses with the help of some graph

# %%
plt.scatter(ds['1Gender of respondent'],ds["2 How old are you? "])
plt.show()

# %%
ax=sns.swarmplot(y="5 Since How Long You are Shopping Online ?",x="Which of the Indian online retailer would you recommend to a friend?",data=ds)
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 30.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 16.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 53.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 18.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# ...

# %%
sns.violinplot(x="1Gender of respondent",data=ds)
# Out:
# <AxesSubplot:xlabel='1Gender of respondent'>

# %%
sns.violinplot(x="5 Since How Long You are Shopping Online ?",data=ds)
# Out:
# <AxesSubplot:xlabel='5 Since How Long You are Shopping Online ?'>

# %%
sns.violinplot(x="6 How many times you have made an online purchase in the past 1 year?",data=ds)
# Out:
# <AxesSubplot:xlabel='6 How many times you have made an online purchase in the past 1 year?'>

# %%
sns.violinplot(x="3 Which city do you shop online from?",data=ds)
# Out:
# <AxesSubplot:xlabel='3 Which city do you shop online from?'>

# %%
sns.violinplot(x="2 How old are you? ",data=ds)
# Out:
# <AxesSubplot:xlabel='2 How old are you? '>

# %%
plt.scatter(ds["2 How old are you? "],ds["Longer time to get logged in (promotion, sales period)"])
plt.show()

# %%
sns.violinplot(x="Longer time to get logged in (promotion, sales period)",data=ds)
# Out:
# <AxesSubplot:xlabel='Longer time to get logged in (promotion, sales period)'>

# %%
ds.columns
# Out:
# Index(['1Gender of respondent', '2 How old are you? ',
#        '3 Which city do you shop online from?',
#        '4 What is the Pin Code of where you shop online from?',
#        '5 Since How Long You are Shopping Online ?',
#        '6 How many times you have made an online purchase in the past 1 year?',
#        '7 How do you access the internet while shopping on-line?',
#        '8 Which device do you use to access the online shopping?',
#        '9 What is the screen size of your mobile device?\t\t\t\t\t\t                                        ',
#        '10 What is the operating system (OS) of your device?\t\t\t\t                                          ',
#        '11 What browser do you run on your device to access the website?\t\t\t                                                          ',
#        '12 Which channel did you follow to arrive at your favorite online store for the first time?                                                                   ',
# ...

# %%
ds['Which of the Indian online retailer would you recommend to a friend?']=le.fit_transform(ds['Which of the Indian online retailer would you recommend to a friend?'])

# %%
sns.violinplot(x='Which of the Indian online retailer would you recommend to a friend?',data=ds)
# Out:
# <AxesSubplot:xlabel='Which of the Indian online retailer would you recommend to a friend?'>

# %%
ds['Website is as efficient as before']=le.fit_transform(ds['Website is as efficient as before'])

# %%
ds['Longer time in displaying graphics and photos (promotion, sales period)']=le.fit_transform(ds['Longer time in displaying graphics and photos (promotion, sales period)'])

# %%
ds['Late declaration of price (promotion, sales period)']=le.fit_transform(ds['Late declaration of price (promotion, sales period)'])

# %%
ds['Website is as efficient as before']=le.fit_transform(ds['Website is as efficient as before'])

# %%
ds['Frequent disruption when moving from one page to another']=le.fit_transform(ds['Frequent disruption when moving from one page to another'])

# %%
ds['Change in website/Application design']=le.fit_transform(ds['Change in website/Application design'])

# %%
ds['Late declaration of price (promotion, sales period)']=le.fit_transform(ds['Longer delivery period'])

# %%
ds['Limited mode of payment on most products (promotion, sales period)']=le.fit_transform(ds['Limited mode of payment on most products (promotion, sales period)'])

# %%
ds['Longer page loading time (promotion, sales period)']=le.fit_transform(ds['Longer page loading time (promotion, sales period)'])

# %%
ds['18 The content on the website must be easy to read and understand']=le.fit_transform(ds['18 The content on the website must be easy to read and understand'])

# %%
ds['21 All relevant information on listed products must be stated clearly']=le.fit_transform(ds['21 All relevant information on listed products must be stated clearly'])

# %%
ds['22 Ease of navigation in website']=le.fit_transform(ds['22 Ease of navigation in website'])

# %%
ds['23 Loading and processing speed']=le.fit_transform(ds['23 Loading and processing speed'])

# %%
ds['24 User friendly Interface of the website']=le.fit_transform(ds['24 User friendly Interface of the website'])

# %%
ds['25 Convenient Payment methods']=le.fit_transform(ds['25 Convenient Payment methods'])

# %%
ds['26 Trust that the online retail store will fulfill its part of the transaction at the stipulated time']=le.fit_transform(ds['26 Trust that the online retail store will fulfill its part of the transaction at the stipulated time'])

# %%
ds['27 Empathy (readiness to assist with queries) towards the customers']=le.fit_transform(ds['27 Empathy (readiness to assist with queries) towards the customers'])

# %%
ds['28 Being able to guarantee the privacy of the customer']=le.fit_transform(ds['28 Being able to guarantee the privacy of the customer'])

# %%
ds['29 Responsiveness, availability of several communication channels (email, online rep, twitter, phone etc.)']=le.fit_transform(ds['29 Responsiveness, availability of several communication channels (email, online rep, twitter, phone etc.)'])

# %%
ds['30 Online shopping gives monetary benefit and discounts']=le.fit_transform(ds['30 Online shopping gives monetary benefit and discounts'])

# %%
ds['31 Enjoyment is derived from shopping online']=le.fit_transform(ds['31 Enjoyment is derived from shopping online'])

# %%
ds['32 Shopping online is convenient and flexible']=le.fit_transform(ds['32 Shopping online is convenient and flexible'])

# %%
ds['35 Displaying quality Information on the website improves satisfaction of customers']=le.fit_transform(ds['35 Displaying quality Information on the website improves satisfaction of customers'])

# %%
ds['36 User derive satisfaction while shopping on a good quality website or application']=le.fit_transform(ds['36 User derive satisfaction while shopping on a good quality website or application'])

# %%
ds['38 User satisfaction cannot exist without trust']=le.fit_transform(ds['38 User satisfaction cannot exist without trust'])

# %%
ds['39 Offering a wide variety of listed product in several category']=le.fit_transform(ds['39 Offering a wide variety of listed product in several category'])

# %%
ds['40 Provision of complete and relevant product information']=le.fit_transform(ds['40 Provision of complete and relevant product information'])

# %%
ds['41 Monetary savings']=le.fit_transform(ds['41 Monetary savings'])

# %%
ds['43 Shopping on the website gives you the sense of adventure']=le.fit_transform(ds['43 Shopping on the website gives you the sense of adventure'])

# %%
ds['43 Shopping on the website gives you the sense of adventure']=le.fit_transform(ds['43 Shopping on the website gives you the sense of adventure'])

# %%
sns.violinplot(x='Website is as efficient as before',data=ds)
# Out:
# <AxesSubplot:xlabel='Website is as efficient as before'>

# %%
sns.violinplot(x='Longer time in displaying graphics and photos (promotion, sales period)',data=ds)
# Out:
# <AxesSubplot:xlabel='Longer time in displaying graphics and photos (promotion, sales period)'>

# %%
sns.violinplot(x='Late declaration of price (promotion, sales period)',data=ds)
# Out:
# <AxesSubplot:xlabel='Late declaration of price (promotion, sales period)'>

# %%
sns.violinplot(x='Late declaration of price (promotion, sales period)',data=ds)
# Out:
# <AxesSubplot:xlabel='Late declaration of price (promotion, sales period)'>

# %%
sns.scatterplot(data=ds,x='Website is as efficient as before',y='Longer time in displaying graphics and photos (promotion, sales period)')
# Out:
# <AxesSubplot:xlabel='Website is as efficient as before', ylabel='Longer time in displaying graphics and photos (promotion, sales period)'>

# %%
sns.scatterplot(data=ds,x='Longer time in displaying graphics and photos (promotion, sales period)',y='Website is as efficient as before')
# Out:
# <AxesSubplot:xlabel='Longer time in displaying graphics and photos (promotion, sales period)', ylabel='Website is as efficient as before'>

# %%
sns.scatterplot(data=ds,x='Limited mode of payment on most products (promotion, sales period)',y='Longer page loading time (promotion, sales period)')
# Out:
# <AxesSubplot:xlabel='Limited mode of payment on most products (promotion, sales period)', ylabel='Longer page loading time (promotion, sales period)'>

# %%
sns.distplot(ds['Which of the Indian online retailer would you recommend to a friend?'],bins=50)
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Which of the Indian online retailer would you recommend to a friend?', ylabel='Density'>

# %%
sns.distplot(ds["5 Since How Long You are Shopping Online ?"],bins=50)
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='5 Since How Long You are Shopping Online ?', ylabel='Density'>

# %%
sns.distplot(ds['43 Shopping on the website gives you the sense of adventure'],bins=50)
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='43 Shopping on the website gives you the sense of adventure', ylabel='Density'>

# %%
sns.distplot(ds['38 User satisfaction cannot exist without trust'],bins=50)
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='38 User satisfaction cannot exist without trust', ylabel='Density'>

# %%
sns.distplot(ds['39 Offering a wide variety of listed product in several category'],bins=50)
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='39 Offering a wide variety of listed product in several category', ylabel='Density'>

# %%
sns.distplot(ds['28 Being able to guarantee the privacy of the customer'],bins=50)
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='28 Being able to guarantee the privacy of the customer', ylabel='Density'>

# %%
sns.scatterplot(data=ds,x='18 The content on the website must be easy to read and understand',y='21 All relevant information on listed products must be stated clearly')
# Out:
# <AxesSubplot:xlabel='18 The content on the website must be easy to read and understand', ylabel='21 All relevant information on listed products must be stated clearly'>

# %%
sns.scatterplot(data=ds,x='1Gender of respondent',y='Which of the Indian online retailer would you recommend to a friend?')
# Out:
# <AxesSubplot:xlabel='1Gender of respondent', ylabel='Which of the Indian online retailer would you recommend to a friend?'>

# %%
sns.scatterplot(data=ds,x='6 How many times you have made an online purchase in the past 1 year?',y='30 Online shopping gives monetary benefit and discounts')
# Out:
# <AxesSubplot:xlabel='6 How many times you have made an online purchase in the past 1 year?', ylabel='30 Online shopping gives monetary benefit and discounts'>

# %%
sns.scatterplot(data=ds,x='8 Which device do you use to access the online shopping?',y="2 How old are you? ")
# Out:
# <AxesSubplot:xlabel='8 Which device do you use to access the online shopping?', ylabel='2 How old are you? '>

# %%
sns.scatterplot(data=ds,x='41 Monetary savings',y='23 Loading and processing speed')
# Out:
# <AxesSubplot:xlabel='41 Monetary savings', ylabel='23 Loading and processing speed'>

# %%
#so till here we do lot os analysis from the hepl of graph ...we perform univariate analysis,multivariate analysis

# %%
#some example of box plot and histplot

# %%
sns.histplot(ds['Which of the Indian online retailer would you recommend to a friend?'])
# Out:
# <AxesSubplot:xlabel='Which of the Indian online retailer would you recommend to a friend?', ylabel='Count'>

# %%
sns.histplot(ds['2 How old are you? '])
# Out:
# <AxesSubplot:xlabel='2 How old are you? ', ylabel='Count'>

# %%
ds['Which of the Indian online retailer would you recommend to a friend?'].plot.box()
# Out:
# <AxesSubplot:>

# %%
ds['41 Monetary savings'].plot.box()
# Out:
# <AxesSubplot:>

# %%
ds['Longer time in displaying graphics and photos (promotion, sales period)'].plot.box()
# Out:
# <AxesSubplot:>

# %%
ds['18 The content on the website must be easy to read and understand'].plot.box()
# Out:
# <AxesSubplot:>

# %%
ds['5 Since How Long You are Shopping Online ?'].plot.box()
# Out:
# <AxesSubplot:>

# %%
ds['Limited mode of payment on most products (promotion, sales period)'].plot.box()
# Out:
# <AxesSubplot:>

# %%
#analysis done
