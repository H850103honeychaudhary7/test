# %% [markdown]
# # ques 1

# %%
import pandas as pd
import selenium
from selenium import webdriver
import time
from selenium.common.exceptions import NoSuchElementException

# %%
driver=webdriver.Chrome(r"C:\Users\DELL\Downloads\chromedriver")
driver.get("https://en.wikipedia.org/wiki/List_of_most-viewed_YouTube_videos")

# %%
vedio_name=driver.find_elements_by_xpath("//table[@class='wikitable sortable jquery-tablesorter'][1]/tbody/tr/td[2]")
vedio_name
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="d81e94d27f14fa01f900f2b75047134a", element="d19aba9d-7dc0-41b9-b380-1c51c979bc6f")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="d81e94d27f14fa01f900f2b75047134a", element="89dc453a-ad09-4caf-8ec1-cc74771a5cd3")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="d81e94d27f14fa01f900f2b75047134a", element="b9ee7b45-dfc3-481a-9a23-d8014b7658a4")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="d81e94d27f14fa01f900f2b75047134a", element="d628a1ed-4445-4560-a671-d91f94fa7e8b")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="d81e94d27f14fa01f900f2b75047134a", element="7a524264-105d-43d8-ad09-6529a2070029")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="d81e94d27f14fa01f900f2b75047134a", element="6765b8ea-e37d-467e-bc25-19a3ee2af6e1")>,
# ...

# %%
name=[]
for i in vedio_name:
    name.append(i.text)
name
# Out:
# ['"Baby Shark Dance"[22]',
#  '"Despacito"[24]',
#  '"Johny Johny Yes Papa"[25]',
#  '"Shape of You"[26]',
#  '"See You Again"[27]',
#  '"Masha and the Bear – Recipe for Disaster"[30]',
#  '"Uptown Funk"[31]',
#  '"Learning Colors – Colorful Eggs on a Farm"[32]',
#  '"Bath Song"[33]',
#  '"Gangnam Style"[34]',
#  '"Phonics Song with Two Words"[36]',
#  '"Sugar"[37]',
#  '"Sorry"[38]',
#  '"Dame Tu Cosita"[39]',
#  '"Roar"[40]',
#  '"Counting Stars"[41]',
#  '"Thinking Out Loud"[42]',
#  '"Dark Horse"[43]',
#  '"Faded"[44]',
#  '"Wheels on the Bus"[45]',
#  '"Shake It Off"[46]',
#  '"Lean On"[47]',
#  '"Girls Like You"[48]',
#  '"Bailando"[49]',
#  '"Let Her Go"[50]',
#  '"Mi Gente"[51]',
#  '"Perfect"[52]',
#  '"Hello"[53]',
#  '"Waka Waka (This Time for Africa)"[54]',
#  '"Axel F"[55]']

# %%
artist_name=driver.find_elements_by_xpath("//table[@class='wikitable sortable jquery-tablesorter'][1]/tbody/tr/td[3]")
artist_name
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="d81e94d27f14fa01f900f2b75047134a", element="f6c0fed2-ca55-4245-aa62-94e557f5f5ba")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="d81e94d27f14fa01f900f2b75047134a", element="5ac5cbf7-4ea0-4417-bb4b-299f0511455b")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="d81e94d27f14fa01f900f2b75047134a", element="3a4d6ae7-df5e-4273-bf18-86b453f44445")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="d81e94d27f14fa01f900f2b75047134a", element="a5b11942-d320-4152-b5a7-3ac17a9a6e80")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="d81e94d27f14fa01f900f2b75047134a", element="de0c5e90-1b24-446f-80cd-aeff6ba560e7")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="d81e94d27f14fa01f900f2b75047134a", element="7273a9aa-9489-46cc-83a9-78c956a33eb3")>,
# ...

# %%
artist=[]
for i in artist_name:
    artist.append(i.text)
artist
# Out:
# ["Pinkfong Kids' Songs & Stories",
#  'Luis Fonsi',
#  'LooLoo Kids',
#  'Ed Sheeran',
#  'Wiz Khalifa',
#  'Get Movies',
#  'Mark Ronson',
#  'Miroshka TV',
#  'Cocomelon – Nursery Rhymes',
#  'Psy',
#  'ChuChu TV',
#  'Maroon 5',
#  'Justin Bieber',
#  'El Chombo',
#  'Katy Perry',
#  'OneRepublic',
#  'Ed Sheeran',
#  'Katy Perry',
#  'Alan Walker',
#  'Cocomelon – Nursery Rhymes',
#  'Taylor Swift',
#  'Major Lazer',
#  'Maroon 5',
#  'Enrique Iglesias',
#  'Passenger',
#  'J Balvin',
#  'Ed Sheeran',
#  'Adele',
#  'Shakira',
#  'Crazy Frog']

# %%
views=driver.find_elements_by_xpath("//table[@class='wikitable sortable jquery-tablesorter'][1]/tbody/tr/td[4]")
views
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="d81e94d27f14fa01f900f2b75047134a", element="d2d7b72a-2603-403f-92ec-5232f394358e")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="d81e94d27f14fa01f900f2b75047134a", element="a935ffc0-89a8-4839-87f8-124721105a1b")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="d81e94d27f14fa01f900f2b75047134a", element="cc378e97-00fb-4a72-ab82-be7efc1dad8f")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="d81e94d27f14fa01f900f2b75047134a", element="a2daffb1-e093-4501-bb3e-bef8ea838e70")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="d81e94d27f14fa01f900f2b75047134a", element="5029a815-2a37-4574-8e25-8a98475a74ee")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="d81e94d27f14fa01f900f2b75047134a", element="fe198577-1b5b-4471-a385-865f96d4e6bb")>,
# ...

# %%
views_billions=[]
for i in views:
    views_billions.append(i.text)
views_billions
# Out:
# ['8.74',
#  '7.39',
#  '5.43',
#  '5.34',
#  '5.13',
#  '4.44',
#  '4.20',
#  '4.14',
#  '4.12',
#  '4.08',
#  '3.91',
#  '3.48',
#  '3.44',
#  '3.38',
#  '3.36',
#  '3.31',
#  '3.27',
#  '3.08',
#  '3.08',
#  '3.07',
#  '3.06',
#  '3.05',
#  '3.04',
#  '3.04',
#  '3.00',
#  '2.93',
#  '2.86',
#  '2.84',
#  '2.84',
#  '2.83']

# %%
upload_date=driver .find_elements_by_xpath("//table[@class='wikitable sortable jquery-tablesorter'][1]/tbody/tr/td[5]")
upload_date
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="d81e94d27f14fa01f900f2b75047134a", element="7b516721-3b74-4da5-9deb-a8474a568f40")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="d81e94d27f14fa01f900f2b75047134a", element="69bdac60-6a76-4b2f-8d3f-9cadfc8b37e6")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="d81e94d27f14fa01f900f2b75047134a", element="d3cb3a5e-0371-4f50-b747-b41e7713242a")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="d81e94d27f14fa01f900f2b75047134a", element="c62588c5-0c4e-4ffb-bbef-87339a6f6fd4")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="d81e94d27f14fa01f900f2b75047134a", element="53007f9c-b879-43b6-b0b0-ddf0c77c3746")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="d81e94d27f14fa01f900f2b75047134a", element="bc4296a5-c8c6-4d0d-90f5-7c7bc9b5dfe7")>,
# ...

# %%
upload=[]
for i in upload_date:
    upload.append(i.text)
upload
# Out:
# ['June 17, 2016',
#  'January 12, 2017',
#  'October 8, 2016',
#  'January 30, 2017',
#  'April 6, 2015',
#  'January 31, 2012',
#  'November 19, 2014',
#  'February 27, 2018',
#  'May 2, 2018',
#  'July 15, 2012',
#  'March 6, 2014',
#  'January 14, 2015',
#  'October 22, 2015',
#  'April 5, 2018',
#  'September 5, 2013',
#  'May 31, 2013',
#  'October 7, 2014',
#  'February 20, 2014',
#  'December 3, 2015',
#  'May 24, 2018',
#  'August 18, 2014',
#  'March 22, 2015',
#  'May 31, 2018',
#  'April 11, 2014',
#  'July 25, 2012',
#  'June 29, 2017',
#  'November 9, 2017',
#  'October 22, 2015',
#  'June 4, 2010',
#  'June 16, 2009']

# %%
import pandas as pd

# %%
top_vedios=pd.DataFrame({})
top_vedios['Name']=name
top_vedios['Artist']=artist
top_vedios['Views(billions)']=views_billions
top_vedios['Upload_Date']=upload

# %%
top_vedios
# Out:
#                                                Name  \
# 0                            "Baby Shark Dance"[22]
# 1                                   "Despacito"[24]
# 2                        "Johny Johny Yes Papa"[25]
# 3                                "Shape of You"[26]
# 4                               "See You Again"[27]
# 5    "Masha and the Bear – Recipe for Disaster"[30]
# 6                                 "Uptown Funk"[31]
# 7   "Learning Colors – Colorful Eggs on a Farm"[32]
# 8                                   "Bath Song"[33]
# 9                               "Gangnam Style"[34]
# 10                "Phonics Song with Two Words"[36]
# 11                                      "Sugar"[37]
# 12                                      "Sorry"[38]
# 13                             "Dame Tu Cosita"[39]
# 14                                       "Roar"[40]
# 15                             "Counting Stars"[41]
# 16                          "Thinking Out Loud"[42]
# ...

# %%
#so here we do not need to use exception handling because all the elemts are clearly seen without error

# %%
driver.close()

# %% [markdown]
# # ques 2

# %%
driver=webdriver.Chrome(r"C:\Users\DELL\Downloads\chromedriver")
driver.get(" https://www.bcci.tv/")

# %%
filter_button=driver.find_elements_by_xpath("//li[@class='footer-navigation__item footer-navigation__item--secondary']//a")

# %%
filter_button
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="abef953be177fedc52bc6f55b2469fef", element="bbb8cf01-1903-4801-9086-a4aad5783629")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="abef953be177fedc52bc6f55b2469fef", element="6068c873-162f-4473-80fc-c12d1f7a6a29")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="abef953be177fedc52bc6f55b2469fef", element="b89dfd7c-d13a-41e8-926e-9848ed8e07b7")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="abef953be177fedc52bc6f55b2469fef", element="26ffccae-4dfe-46d8-9aa2-83d134121adf")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="abef953be177fedc52bc6f55b2469fef", element="b92d03ac-1b38-4ab7-b262-7ef89a878874")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="abef953be177fedc52bc6f55b2469fef", element="03942047-f045-4129-a460-6b957d66fb93")>,
# ...

# %%
button=[]
for i in filter_button:
    button.append(i.text)
button
# Out:
# ['Home',
#  'News',
#  'Features',
#  'Press Releases',
#  'Fixtures',
#  'Results',
#  'Series & Tournaments',
#  'Archive',
#  'Fixtures',
#  'Results',
#  'Series & Tournaments',
#  'Archive',
#  'Latest Videos',
#  'Highlights',
#  'Features & Interviews',
#  'Press Conferences',
#  'Team India Men',
#  'Team India Women',
#  'Photos Home',
#  'About',
#  'BCCI Constitution',
#  'Venues',
#  'Polls',
#  'Jobs']

# %%
date_day_time=driver.find_elements_by_xpath("//span[@class='fixture__datetime tablet-only']")
date_day_time
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="abef953be177fedc52bc6f55b2469fef", element="aba0e6aa-4a08-46a1-a249-8c19ebfd58ef")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="abef953be177fedc52bc6f55b2469fef", element="776e8bcb-cfda-4165-ae3c-e60d8ff9dc4b")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="abef953be177fedc52bc6f55b2469fef", element="951cdff7-f890-4fbe-970e-9b8ccea50ead")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="abef953be177fedc52bc6f55b2469fef", element="c08478ea-e978-4d9c-a94b-22497e2fb5f9")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="abef953be177fedc52bc6f55b2469fef", element="64ff5d92-6783-449a-8159-7c64b1c9c810")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="abef953be177fedc52bc6f55b2469fef", element="7c7a84bf-495a-4785-8078-5eaf8fba0ec6")>,
# ...

# %%
Date_Day_Time=[]
for i in date_day_time:
    Date_Day_Time.append(i.text)
Date_Day_Time
# Out:
# ['Friday 18th June 15:00 IST (02:30 Your Time )',
#  'Tuesday 13th July 14:30 IST (02:00 Your Time )',
#  'Friday 16th July 14:30 IST (02:00 Your Time )',
#  'Sunday 18th July 14:30 IST (02:00 Your Time )',
#  'Wednesday 21st July 19:00 IST (06:30 Your Time )',
#  'Friday 23rd July 19:00 IST (06:30 Your Time )',
#  'Sunday 25th July 19:00 IST (06:30 Your Time )',
#  'Wednesday 4th August 15:30 IST (03:00 Your Time )',
#  'Thursday 12th August 15:30 IST (03:00 Your Time )',
#  'Wednesday 25th August 15:30 IST (03:00 Your Time )',
#  'Thursday 2nd September 15:30 IST (03:00 Your Time )',
#  'Friday 10th September 15:30 IST (03:00 Your Time )']

# %%
venue_tag=driver.find_elements_by_xpath("//p[@class='fixture__additional-info']")
venue_tag
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="abef953be177fedc52bc6f55b2469fef", element="29d78ef1-890c-40b5-98da-914d4e96d076")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="abef953be177fedc52bc6f55b2469fef", element="044358b0-426d-48d1-94b2-4bcbb0626964")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="abef953be177fedc52bc6f55b2469fef", element="1868611d-b168-4734-b1e8-0db47fbf8357")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="abef953be177fedc52bc6f55b2469fef", element="343a663e-aad6-4684-9084-8e7db797d2d5")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="abef953be177fedc52bc6f55b2469fef", element="05eb71bf-0c6e-4587-bc54-d4425eb73873")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="abef953be177fedc52bc6f55b2469fef", element="15b693a8-2f0e-4fe4-a07f-1caeed184003")>,
# ...

# %%
Venue=[]
for i in venue_tag:
    Venue.append(i.text)
Venue
# Out:
# ['Final The Ageas Bowl, Southampton',
#  '1st ODI R Premadasa Stadium, Colombo',
#  '2nd ODI R Premadasa Stadium, Colombo',
#  '3rd ODI R Premadasa Stadium, Colombo',
#  '1st T20I R Premadasa Stadium, Colombo',
#  '2nd T20I R Premadasa Stadium, Colombo',
#  '3rd T20I R Premadasa Stadium, Colombo',
#  '1st Test Trent Bridge, Nottingham',
#  "2nd Test Lord's, London",
#  '3rd Test Headingley, Leeds',
#  '4th Test The Oval, London',
#  '5th Test Old Trafford, Manchester']

# %%
Teams_tag=driver.find_elements_by_xpath("//div[@class='fixture__teams']")
Teams_tag
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="abef953be177fedc52bc6f55b2469fef", element="8b3f20cb-9cb1-4b10-af16-e45a8afced30")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="abef953be177fedc52bc6f55b2469fef", element="aabeade9-cff0-44d6-a300-030e5e2c9e53")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="abef953be177fedc52bc6f55b2469fef", element="c8361199-c9f5-46a8-8d4e-2220733ac738")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="abef953be177fedc52bc6f55b2469fef", element="2cb05e7e-bcc6-4055-a627-2797ce7b29db")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="abef953be177fedc52bc6f55b2469fef", element="28b53adc-c459-4861-b2aa-7e96e334f2a9")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="abef953be177fedc52bc6f55b2469fef", element="f13efe62-86d0-4ecb-bbe0-9d6d3eb0f373")>,
# ...

# %%
Teams=[]
for i in Teams_tag:
    Teams.append(i.text)
Teams
# Out:
# ['INDIA\nNEW ZEALAND',
#  'SRI LANKA\nINDIA',
#  'SRI LANKA\nINDIA',
#  'SRI LANKA\nINDIA',
#  'SRI LANKA\nINDIA',
#  'SRI LANKA\nINDIA',
#  'SRI LANKA\nINDIA',
#  'ENGLAND\nINDIA',
#  'ENGLAND\nINDIA',
#  'ENGLAND\nINDIA',
#  'ENGLAND\nINDIA',
#  'ENGLAND\nINDIA']

# %%
import pandas as pd
Fixtures=pd.DataFrame({})
Fixtures['Teams']=Teams
Fixtures['Venue']=Venue
Fixtures['Date_Day_Time']=Date_Day_Time

# %%
Fixtures
# Out:
#                  Teams                                  Venue  \
# 0   INDIA\nNEW ZEALAND      Final The Ageas Bowl, Southampton
# 1     SRI LANKA\nINDIA   1st ODI R Premadasa Stadium, Colombo
# 2     SRI LANKA\nINDIA   2nd ODI R Premadasa Stadium, Colombo
# 3     SRI LANKA\nINDIA   3rd ODI R Premadasa Stadium, Colombo
# 4     SRI LANKA\nINDIA  1st T20I R Premadasa Stadium, Colombo
# 5     SRI LANKA\nINDIA  2nd T20I R Premadasa Stadium, Colombo
# 6     SRI LANKA\nINDIA  3rd T20I R Premadasa Stadium, Colombo
# 7       ENGLAND\nINDIA      1st Test Trent Bridge, Nottingham
# 8       ENGLAND\nINDIA                2nd Test Lord's, London
# 9       ENGLAND\nINDIA             3rd Test Headingley, Leeds
# 10      ENGLAND\nINDIA              4th Test The Oval, London
# 11      ENGLAND\nINDIA      5th Test Old Trafford, Manchester
#
#                                         Date_Day_Time
# 0       Friday 18th June 15:00 IST (02:30 Your Time )
# ...

# %%
driver.close()

# %% [markdown]
# # ques3

# %%
driver=webdriver.Chrome(r"C:\Users\DELL\Downloads\chromedriver")

# %%
url=' https://www.guru99.com/exception-handling-selenium.html'
driver.get(url)

# %%
name_tag=driver.find_elements_by_xpath("//table[@class='table table-striped']/tbody/tr/td[1]")
name_tag
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="54abea11cd548bb1d3efb44926d8b0f3", element="dc922255-f957-4c65-b048-be5e2ad6e157")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="54abea11cd548bb1d3efb44926d8b0f3", element="9d0db229-ded3-45b0-9fcb-3a7156093d9b")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="54abea11cd548bb1d3efb44926d8b0f3", element="9d7117fe-ad98-4a0e-8200-0a493debc9e5")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="54abea11cd548bb1d3efb44926d8b0f3", element="46f7de42-0fc3-4ddd-a8c2-01e9a72fc986")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="54abea11cd548bb1d3efb44926d8b0f3", element="e6fa0fda-962d-4818-b683-821fa34fcc8a")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="54abea11cd548bb1d3efb44926d8b0f3", element="3365ca6b-eb7d-4abb-a520-ffa01eef57d1")>,
# ...

# %%
name=[]
for i in name_tag:
    name.append(i.text)
name
# Out:
# ['Exception name',
#  'ElementNotVisibleException',
#  'ElementNotSelectableException',
#  'NoSuchElementException',
#  'NoSuchFrameException',
#  'NoAlertPresentException',
#  'NoSuchWindowException',
#  'StaleElementReferenceException',
#  'SessionNotFoundException',
#  'TimeoutException',
#  'WebDriverException',
#  'ConnectionClosedException',
#  'ElementClickInterceptedException',
#  'ElementNotInteractableException',
#  'ErrorInResponseException',
#  'ErrorHandler.UnknownServerException',
#  'ImeActivationFailedException',
#  'ImeNotAvailableException',
#  'InsecureCertificateException',
#  'InvalidArgumentException',
#  'InvalidCookieDomainException',
#  'InvalidCoordinatesException',
#  'InvalidElementStateExceptio',
#  'InvalidSessionIdException',
#  'InvalidSwitchToTargetException',
#  'JavascriptException',
#  'JsonException',
#  'NoSuchAttributeException',
#  'MoveTargetOutOfBoundsException',
#  'NoSuchContextException',
#  'NoSuchCookieException',
# ...

# %%
description_tag=driver.find_elements_by_xpath("//table[@class='table table-striped']/tbody/tr/td[2]")
description_tag
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="54abea11cd548bb1d3efb44926d8b0f3", element="e141bc1d-3111-4740-8b39-22fd2aea4d0d")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="54abea11cd548bb1d3efb44926d8b0f3", element="86581bcf-cc78-4d31-8820-64b3dc067168")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="54abea11cd548bb1d3efb44926d8b0f3", element="c80e7e1c-9f01-496f-b0d6-91713d5a1214")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="54abea11cd548bb1d3efb44926d8b0f3", element="a66c8d62-8802-499a-91a2-43d52735ee8d")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="54abea11cd548bb1d3efb44926d8b0f3", element="14ea3edc-ff0a-40ee-aad7-8cd435ecce6c")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="54abea11cd548bb1d3efb44926d8b0f3", element="b5c7a60e-3d69-4d78-b6a7-a38d1d726bcc")>,
# ...

# %%
description=[]
for i in description_tag:
    description.append(i.text)
description
# Out:
# ['Description',
#  'This type of Selenium exception occurs when an existing element in DOM has a feature set as hidden.',
#  'This Selenium exception occurs when an element is presented in the DOM, but you can be able to select. Therefore, it is not possible to interact.',
#  'This Exception occurs if an element could not be found.',
#  'This Exception occurs if the frame target to be switched to does not exist.',
#  'This Exception occurs when you switch to no presented alert.',
#  'This Exception occurs if the window target to be switch does not exist.',
#  'This Selenium exception occurs happens when the web element is detached from the current DOM.',
#  'The WebDriver is acting after you quit the browser.',
#  "Thrown when there is not enough time for a command to be completed. For Example, the element searched wasn't found in the specified time.",
#  'This Exception takes place when the WebDriver is acting right after you close the browser.',
# ...

# %%
import pandas as pd

# %%
exc_handling=pd.DataFrame({})
exc_handling['Name']=name
exc_handling['Description']=description

# %%
exc_handling
# Out:
#                                    Name  \
# 0                        Exception name
# 1            ElementNotVisibleException
# 2         ElementNotSelectableException
# 3                NoSuchElementException
# 4                  NoSuchFrameException
# 5               NoAlertPresentException
# 6                 NoSuchWindowException
# 7        StaleElementReferenceException
# 8              SessionNotFoundException
# 9                      TimeoutException
# 10                   WebDriverException
# 11            ConnectionClosedException
# 12     ElementClickInterceptedException
# 13      ElementNotInteractableException
# 14             ErrorInResponseException
# 15  ErrorHandler.UnknownServerException
# 16         ImeActivationFailedException
# 17             ImeNotAvailableException
# 18         InsecureCertificateException
# 19             InvalidArgumentException
# 20         InvalidCookieDomainException
# 21          InvalidCoordinatesException
# ...

# %% [markdown]
# # ques 6

# %%
driver=webdriver.Chrome(r"C:\Users\DELL\Downloads\chromedriver")
driver.get("https://www.billboard.com/charts/hot-100")

# %%
name=[]
try:
    names=driver.find_elements_by_xpath("//span[@class='chart-element__information__song text--truncate color--primary']")
    for i in names[1:]:
        name.append(i.text)
except NoSuchElementException:
        name.append('No Details available')
        
print(len(name))
# Out:
# 99

# %%
name
# Out:
# ['Good 4 U',
#  'Levitating',
#  'Peaches',
#  'Leave The Door Open',
#  'Save Your Tears',
#  'Kiss Me More',
#  'Astronaut In The Ocean',
#  'Deja Vu',
#  'Yonaguni',
#  'Montero (Call Me By Your Name)',
#  'Without You',
#  'Forever After All',
#  'Rapstar',
#  'Blinding Lights',
#  'Hats Off',
#  'Drivers License',
#  'Beautiful Mistakes',
#  'Traitor',
#  'Late At Night',
#  'Voice Of The Heroes',
#  'Best Friend',
#  'Heartbreak Anniversary',
#  'Heat Waves',
#  'Calling My Phone',
#  'Favorite Crime',
#  'Lost Cause',
#  'Happier',
#  'Up',
#  'Mood',
#  '2040',
#  'Every Chance I Get',
#  'Telepatia',
#  'How It Feels',
#  'Brutal',
#  'Wockesha',
#  'Wants And Needs',
#  'Famous Friends',
#  'pov',
#  'Gone',
#  'Beat Box',
#  "My Ex's Best Friend",
#  'Still Runnin',
#  'Track Star',
#  'What You Know Bout Love',
#  'Who I Want',
#  'my.life',
#  'Back In Blood',
#  'Time Today',
#  'Lil Bit',
#  'Blame It On You',
#  'Nobody',
#  'Todo de Ti',
#  'Enough For You',
# ...

# %%
artist=[]
try:
    artists=driver.find_elements_by_xpath("//span[@class='chart-element__information__artist text--truncate color--secondary']")
    for i in artists[1:]:
        artist.append(i.text)
except NoSuchElementException:
    artist.append('No details available')
print(len(artist))
# Out:
# 99

# %%
artist
# Out:
# ['Olivia Rodrigo',
#  'Dua Lipa Featuring DaBaby',
#  'Justin Bieber Featuring Daniel Caesar & Giveon',
#  'Silk Sonic (Bruno Mars & Anderson .Paak)',
#  'The Weeknd & Ariana Grande',
#  'Doja Cat Featuring SZA',
#  'Masked Wolf',
#  'Olivia Rodrigo',
#  'Bad Bunny',
#  'Lil Nas X',
#  'The Kid LAROI',
#  'Luke Combs',
#  'Polo G',
#  'The Weeknd',
#  'Lil Baby, Lil Durk & Travis Scott',
#  'Olivia Rodrigo',
#  'Maroon 5 Featuring Megan Thee Stallion',
#  'Olivia Rodrigo',
#  'Roddy Ricch',
#  'Lil Baby & Lil Durk',
#  'Saweetie Featuring Doja Cat',
#  'Giveon',
#  'Glass Animals',
#  'Lil Tjay Featuring 6LACK',
#  'Olivia Rodrigo',
#  'Billie Eilish',
#  'Olivia Rodrigo',
#  'Cardi B',
#  '24kGoldn Featuring iann dior',
#  'Lil Baby & Lil Durk',
#  'DJ Khaled Featuring Lil Baby & Lil Durk',
#  'Kali Uchis',
#  'Lil Baby & Lil Durk',
#  'Olivia Rodrigo',
#  'Moneybagg Yo',
#  'Drake Featuring Lil Baby',
#  'Chris Young + Kane Brown',
#  'Ariana Grande',
#  'Dierks Bentley',
# ...

# %%
last_week=[]
try:
    las_week=driver.find_elements_by_xpath("//div[@class='chart-element__meta text--center color--secondary text--last']")
    for i in las_week[1:]:
        last_week.append(i.text)
except NoSuchElementException:
    last_week.append('No details available')
    
print(len(last_week))
# Out:
# 99

# %%
last_week
# Out:
# ['2',
#  '3',
#  '6',
#  '4',
#  '5',
#  '7',
#  '9',
#  '8',
#  '-',
#  '10',
#  '11',
#  '15',
#  '14',
#  '17',
#  '-',
#  '13',
#  '18',
#  '12',
#  '-',
#  '81',
#  '22',
#  '23',
#  '25',
#  '21',
#  '16',
#  '-',
#  '20',
#  '24',
#  '30',
#  '-',
#  '26',
#  '34',
#  '-',
#  '19',
#  '33',
#  '39',
#  '43',
#  '37',
#  '36',
#  '29',
#  '31',
#  '-',
#  '32',
#  '41',
#  '-',
#  '28',
#  '35',
#  '48',
#  '53',
#  '63',
#  '50',
#  '66',
#  '27',
#  '47',
#  '-',
#  '42',
#  '-',
#  '51',
#  '-',
#  '56',
#  '49',
#  '68',
#  '45',
#  '38',
#  '55',
#  '-',
#  '-',
#  '72',
#  '-',
#  '-',
#  '70',
#  '-',
#  '57',
#  '60',
#  '59',
#  '54',
#  '71',
#  '-',
#  '-',
#  '69',
#  '58',
#  '77',
#  '52',
#  '73',
#  '85',
#  '78',
#  '61',
#  '75',
#  '86',
#  '87',
#  '64',
#  '74',
#  '79',
#  '76',
#  '93',
#  '89',
#  '92',
#  '-',
#  '67']

# %%
peak=[]
try:
    peak_tag=driver.find_elements_by_xpath("//div[@class='chart-element__meta text--center color--secondary text--peak']")
    for i in peak_tag[1:]:
        peak.append(i.text)
except NoSuchElementException:
    peak.append('No details available')
print(len(peak))
# Out:
# 99

# %%
peak
# Out:
# ['1',
#  '2',
#  '1',
#  '1',
#  '1',
#  '5',
#  '6',
#  '3',
#  '10',
#  '1',
#  '8',
#  '2',
#  '1',
#  '1',
#  '16',
#  '1',
#  '18',
#  '9',
#  '20',
#  '21',
#  '14',
#  '17',
#  '24',
#  '3',
#  '16',
#  '27',
#  '15',
#  '1',
#  '1',
#  '31',
#  '20',
#  '33',
#  '34',
#  '12',
#  '33',
#  '2',
#  '38',
#  '37',
#  '36',
#  '12',
#  '20',
#  '43',
#  '31',
#  '9',
#  '46',
#  '2',
#  '13',
#  '31',
#  '50',
#  '51',
#  '50',
#  '53',
#  '14',
#  '47',
#  '56',
#  '24',
#  '58',
#  '51',
#  '60',
#  '56',
#  '32',
#  '63',
#  '7',
#  '19',
#  '18',
#  '67',
#  '68',
#  '69',
#  '70',
#  '71',
#  '70',
#  '73',
#  '32',
#  '10',
#  '26',
#  '31',
#  '62',
#  '79',
#  '80',
#  '69',
#  '11',
#  '77',
#  '29',
#  '65',
#  '78',
#  '38',
#  '33',
#  '75',
#  '68',
#  '87',
#  '64',
#  '67',
#  '11',
#  '1',
#  '93',
#  '73',
#  '79',
#  '99',
#  '12']

# %%
woc=[]
try:
    w_on_chart=driver.find_elements_by_xpath("//div[@class='chart-element__meta text--center color--secondary text--week']")
    for i in w_on_chart[1:]:
        woc.append(i.text)
except NoSuchElementException:
    woc.append('No details available')
print(len(woc))
# Out:
# 99

# %%
woc
# Out:
# ['4',
#  '36',
#  '12',
#  '14',
#  '26',
#  '9',
#  '17',
#  '10',
#  '1',
#  '11',
#  '27',
#  '33',
#  '9',
#  '79',
#  '1',
#  '22',
#  '14',
#  '3',
#  '1',
#  '2',
#  '22',
#  '17',
#  '21',
#  '17',
#  '3',
#  '1',
#  '3',
#  '18',
#  '44',
#  '1',
#  '6',
#  '16',
#  '1',
#  '3',
#  '7',
#  '14',
#  '11',
#  '14',
#  '13',
#  '21',
#  '43',
#  '1',
#  '16',
#  '40',
#  '1',
#  '4',
#  '23',
#  '18',
#  '12',
#  '7',
#  '15',
#  '2',
#  '3',
#  '13',
#  '1',
#  '3',
#  '1',
#  '20',
#  '1',
#  '4',
#  '15',
#  '18',
#  '4',
#  '3',
#  '8',
#  '1',
#  '1',
#  '3',
#  '1',
#  '1',
#  '6',
#  '1',
#  '16',
#  '6',
#  '18',
#  '17',
#  '26',
#  '1',
#  '1',
#  '5',
#  '5',
#  '7',
#  '3',
#  '18',
#  '9',
#  '4',
#  '3',
#  '2',
#  '10',
#  '7',
#  '2',
#  '10',
#  '12',
#  '14',
#  '4',
#  '6',
#  '7',
#  '1',
#  '4']

# %%
hot100=pd.DataFrame({})
hot100['Name']=name
hot100['Artist']=artist
hot100['LastWeek']=last_week
hot100['Peak']=peak
hot100['WOC']=woc

# %%
hot100
# Out:
#                                  Name  \
# 0                            Good 4 U
# 1                          Levitating
# 2                             Peaches
# 3                 Leave The Door Open
# 4                     Save Your Tears
# ..                                ...
# 94           Things A Man Oughta Know
# 95                      Country Again
# 96  Drunk (And I Don't Wanna Go Home)
# 97                     If You Want To
# 98                       Seeing Green
#
#                                             Artist LastWeek Peak WOC
# 0                                   Olivia Rodrigo        2    1   4
# 1                        Dua Lipa Featuring DaBaby        3    2  36
# 2   Justin Bieber Featuring Daniel Caesar & Giveon        6    1  12
# 3         Silk Sonic (Bruno Mars & Anderson .Paak)        4    1  14
# 4                       The Weeknd & Ariana Grande        5    1  26
# ..                                             ...      ...  ...  ..
# ...

# %%
driver.close()

# %% [markdown]
# # ques 8

# %%
driver=webdriver.Chrome(r"C:\Users\DELL\Downloads\chromedriver")
driver.get("https://www.theguardian.com/news/datablog/2012/aug/09/best-selling-books-all-time-fifty-shades-grey-compare")

# %%
title_tags=driver.find_elements_by_xpath("//table[@class='in-article sortable'][1]/tbody/tr/td[2]")
title_tags
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="8c587f349c472162f4ee1f5e68eba225", element="6324d178-5763-4c3a-8946-0c017e453064")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8c587f349c472162f4ee1f5e68eba225", element="621ff24a-9b11-4a91-9bfb-f6a3f1654e75")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8c587f349c472162f4ee1f5e68eba225", element="09a4a48a-9b07-479f-b4ad-18c34cfd9f56")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8c587f349c472162f4ee1f5e68eba225", element="f7363127-dfb8-4f2a-873b-41971f53c25b")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8c587f349c472162f4ee1f5e68eba225", element="6027a819-fb65-4221-987d-5f5d9373e9e9")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8c587f349c472162f4ee1f5e68eba225", element="c256e0f7-1d15-4ef5-838d-0d05ce591d09")>,
# ...

# %%
title=[]
for i in title_tags:
    title.append(i.text)
title
# Out:
# ['Da Vinci Code,The',
#  'Harry Potter and the Deathly Hallows',
#  "Harry Potter and the Philosopher's Stone",
#  'Harry Potter and the Order of the Phoenix',
#  'Fifty Shades of Grey',
#  'Harry Potter and the Goblet of Fire',
#  'Harry Potter and the Chamber of Secrets',
#  'Harry Potter and the Prisoner of Azkaban',
#  'Angels and Demons',
#  "Harry Potter and the Half-blood Prince:Children's Edition",
#  'Fifty Shades Darker',
#  'Twilight',
#  'Girl with the Dragon Tattoo,The:Millennium Trilogy',
#  'Fifty Shades Freed',
#  'Lost Symbol,The',
#  'New Moon',
#  'Deception Point',
#  'Eclipse',
#  'Lovely Bones,The',
#  'Curious Incident of the Dog in the Night-time,The',
#  'Digital Fortress',
#  'Short History of Nearly Everything,A',
#  'Girl Who Played with Fire,The:Millennium Trilogy',
#  'Breaking Dawn',
#  'Very Hungry Caterpillar,The:The Very Hungry Caterpillar',
#  'Gruffalo,The',
#  "Jamie's 30-Minute Meals",
#  'Kite Runner,The',
#  'One Day',
# ...

# %%
Author=[]
try:
    author_tag=driver.find_elements_by_xpath("//table[@class='in-article sortable'][1]/tbody/tr/td[3]")
    for i in author_tag[:]:
        Author.append(i.text)
except NoSuchElementException:
    Author.append('No details available')
    
print(len(Author))
# Out:
# 100

# %%
Author
# Out:
# ['Brown, Dan',
#  'Rowling, J.K.',
#  'Rowling, J.K.',
#  'Rowling, J.K.',
#  'James, E. L.',
#  'Rowling, J.K.',
#  'Rowling, J.K.',
#  'Rowling, J.K.',
#  'Brown, Dan',
#  'Rowling, J.K.',
#  'James, E. L.',
#  'Meyer, Stephenie',
#  'Larsson, Stieg',
#  'James, E. L.',
#  'Brown, Dan',
#  'Meyer, Stephenie',
#  'Brown, Dan',
#  'Meyer, Stephenie',
#  'Sebold, Alice',
#  'Haddon, Mark',
#  'Brown, Dan',
#  'Bryson, Bill',
#  'Larsson, Stieg',
#  'Meyer, Stephenie',
#  'Carle, Eric',
#  'Donaldson, Julia',
#  'Oliver, Jamie',
#  'Hosseini, Khaled',
#  'Nicholls, David',
#  'Hosseini, Khaled',
#  'Larsson, Stieg',
#  'Niffenegger, Audrey',
#  'McEwan, Ian',
#  'Fielding, Helen',
#  'Clarkson, Jeremy',
#  'Bernieres, Louis de',
#  'Kay, Peter',
#  'Martel, Yann',
#  'Stephenson, Pamela',
#  'Pelzer, Dave',
#  'Donaldson, Julia',
#  'McCourt, Frank',
#  'Faulks, Sebastian',
#  'Pullman, Philip',
#  'Mosse, Kate',
#  'Rowling, J.K.',
#  'Stockett, Kathryn',
#  'Parsons, Tony',
# ...

# %%
Volume_sold=[]
try:
    volume=driver.find_elements_by_xpath("//table[@class='in-article sortable'][1]/tbody/tr/td[4]")
    for i in volume[:]:
        Volume_sold.append(i.text)
except NoSuchElementException:
    Volume_sold.append('No details found')
    
print(len(Volume_sold))
# Out:
# 100

# %%
Volume_sold
# Out:
# ['5,094,805',
#  '4,475,152',
#  '4,200,654',
#  '4,179,479',
#  '3,758,936',
#  '3,583,215',
#  '3,484,047',
#  '3,377,906',
#  '3,193,946',
#  '2,950,264',
#  '2,479,784',
#  '2,315,405',
#  '2,233,570',
#  '2,193,928',
#  '2,183,031',
#  '2,152,737',
#  '2,062,145',
#  '2,052,876',
#  '2,005,598',
#  '1,979,552',
#  '1,928,900',
#  '1,852,919',
#  '1,814,784',
#  '1,787,118',
#  '1,783,535',
#  '1,781,269',
#  '1,743,266',
#  '1,629,119',
#  '1,616,068',
#  '1,583,992',
#  '1,555,135',
#  '1,546,886',
#  '1,539,428',
#  '1,508,205',
#  '1,489,403',
#  '1,352,318',
#  '1,310,207',
#  '1,310,176',
#  '1,231,957',
#  '1,217,712',
#  '1,208,711',
#  '1,204,058',
#  '1,184,967',
#  '1,181,503',
#  '1,181,093',
#  '1,153,181',
#  '1,132,336',
#  '1,130,802',
#  '1,126,337',
#  '1,115,549',
#  '1,108,328',
#  '1,107,379',
#  '1,104,403',
#  '1,092,349',
#  '1,090,847',
#  '1,087,262',
#  '1,054,196',
#  '1,037,160',
#  '1,023,688',
#  '1,015,956',
#  '1,009,873',
#  '1,004,414',
# ...

# %%
Publisher=[]
try:
    publish_tag=driver.find_elements_by_xpath("//table[@class='in-article sortable'][1]/tbody/tr/td[5]")
    for i in publish_tag[:]:
        Publisher.append(i.text)
except NoSuchElementException:
    Publisher.append('No details found')
    
print(len(Publisher))
# Out:
# 100

# %%
Publisher
# Out:
# ['Transworld',
#  'Bloomsbury',
#  'Bloomsbury',
#  'Bloomsbury',
#  'Random House',
#  'Bloomsbury',
#  'Bloomsbury',
#  'Bloomsbury',
#  'Transworld',
#  'Bloomsbury',
#  'Random House',
#  'Little, Brown Book',
#  'Quercus',
#  'Random House',
#  'Transworld',
#  'Little, Brown Book',
#  'Transworld',
#  'Little, Brown Book',
#  'Pan Macmillan',
#  'Random House',
#  'Transworld',
#  'Transworld',
#  'Quercus',
#  'Little, Brown Book',
#  'Penguin',
#  'Pan Macmillan',
#  'Penguin',
#  'Bloomsbury',
#  'Hodder & Stoughton',
#  'Bloomsbury',
#  'Quercus',
#  'Random House',
#  'Random House',
#  'Pan Macmillan',
#  'Penguin',
#  'Random House',
#  'Random House',
#  'Canongate',
#  'HarperCollins',
#  'Orion',
#  'Pan Macmillan',
#  'HarperCollins',
#  'Random House',
#  'Scholastic Ltd.',
#  'Orion',
#  'Bloomsbury',
#  'Penguin',
#  'HarperCollins',
#  'Random House',
#  'Little, Brown Book',
#  'Headline',
#  'HarperCollins',
#  'Penguin',
#  'Orion',
#  'Bloomsbury',
# ...

# %%
Genre=[]
try:
    genre_tag=driver.find_elements_by_xpath("//table[@class='in-article sortable'][1]/tbody/tr/td[6]")
    for i in genre_tag[:]:
        Genre.append(i.text)
except NosuchElementException:
    Genre.append('No details found')
print(len(Genre))
# Out:
# 100

# %%
Genre
# Out:
# ['Crime, Thriller & Adventure',
#  "Children's Fiction",
#  "Children's Fiction",
#  "Children's Fiction",
#  'Romance & Sagas',
#  "Children's Fiction",
#  "Children's Fiction",
#  "Children's Fiction",
#  'Crime, Thriller & Adventure',
#  "Children's Fiction",
#  'Romance & Sagas',
#  'Young Adult Fiction',
#  'Crime, Thriller & Adventure',
#  'Romance & Sagas',
#  'Crime, Thriller & Adventure',
#  'Young Adult Fiction',
#  'Crime, Thriller & Adventure',
#  'Young Adult Fiction',
#  'General & Literary Fiction',
#  'General & Literary Fiction',
#  'Crime, Thriller & Adventure',
#  'Popular Science',
#  'Crime, Thriller & Adventure',
#  'Young Adult Fiction',
#  'Picture Books',
#  'Picture Books',
#  'Food & Drink: General',
#  'General & Literary Fiction',
#  'General & Literary Fiction',
#  'General & Literary Fiction',
#  'Crime, Thriller & Adventure',
#  'General & Literary Fiction',
#  'General & Literary Fiction',
#  'General & Literary Fiction',
# ...

# %%
Novel=pd.DataFrame({})
Novel['Title']=title
Novel['Author']=Author
Novel['Volume_sold']=Volume_sold
Novel['Publisher']=Publisher
Novel['Ganre']=Genre

# %%
Novel
# Out:
#                                                 Title            Author  \
# 0                                   Da Vinci Code,The        Brown, Dan
# 1                Harry Potter and the Deathly Hallows     Rowling, J.K.
# 2            Harry Potter and the Philosopher's Stone     Rowling, J.K.
# 3           Harry Potter and the Order of the Phoenix     Rowling, J.K.
# 4                                Fifty Shades of Grey      James, E. L.
# ..                                                ...               ...
# 95                                          Ghost,The    Harris, Robert
# 96                     Happy Days with the Naked Chef     Oliver, Jamie
# 97              Hunger Games,The:Hunger Games Trilogy  Collins, Suzanne
# 98  Lost Boy,The:A Foster Child's Search for the L...      Pelzer, Dave
# 99  Jamie's Ministry of Food:Anyone Can Learn to C...     Oliver, Jamie
#
#    Volume_sold        Publisher                        Ganre
# ...

# %%
driver.close()

# %% [markdown]
# # ques 9

# %%
driver=webdriver.Chrome(r"C:\Users\DELL\Downloads\chromedriver")
driver.get('https://www.imdb.com/list/ls095964455/')

# %%
year_tag=driver.find_elements_by_xpath("//span[@class='lister-item-year text-muted unbold']")
year_tag
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="38483d049f10acc130e94c1a03dd76a4", element="c9cb0f8e-0531-46b4-9fb4-ffc377cc1b46")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="38483d049f10acc130e94c1a03dd76a4", element="81ea09d8-67fa-476c-9809-e0a6cacbefe2")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="38483d049f10acc130e94c1a03dd76a4", element="2aab01eb-7e3e-462b-a16e-b7f02d16d62e")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="38483d049f10acc130e94c1a03dd76a4", element="6c3b0287-c6ab-4b62-ac73-eeb71b2ed60c")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="38483d049f10acc130e94c1a03dd76a4", element="b5cc0289-63e8-46c8-85e5-3a697d20b8ca")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="38483d049f10acc130e94c1a03dd76a4", element="85bf9508-5f55-43a4-9411-a3a20ae2d137")>,
# ...

# %%
Year_span=[]
for i in year_tag:
    Year_span.append(i.text)
Year_span
# Out:
# ['(2011–2019)',
#  '(2016– )',
#  '(2010–2022)',
#  '(2017–2020)',
#  '(2014–2020)',
#  '(2013–2019)',
#  '(2017– )',
#  '(2005– )',
#  '(2014– )',
#  '(2012–2020)',
#  '(2017–2021)',
#  '(2007–2019)',
#  '(2011– )',
#  '(2010–2017)',
#  '(2013–2020)',
#  '(2010–2017)',
#  '(2009–2017)',
#  '(2011– )',
#  '(2008–2013)',
#  '(2016– )',
#  '(2005–2020)',
#  '(2005–2017)',
#  '(2014–2020)',
#  '(2011–2017)',
#  '(1989– )',
#  '(2011–2018)',
#  '(2015–2017)',
#  '(2015–2018)',
#  '(1994–2004)',
#  '(2005–2014)',
#  '(2011–2019)',
#  '(2015–2019)',
#  '(2013–2018)',
#  '(2015–2021)',
#  '(2007–2012)',
#  '(2015–2018)',
#  '(2014–2019)',
#  '(2016– )',
#  '(2015–2019)',
#  '(2009–2020)',
#  '(2013– )',
#  '(2016–2019)',
#  '(2017–2019)',
#  '(2013–2018)',
#  '(2017–2020)',
#  '(2018– )',
#  '(2019– )',
#  '(2011–2021)',
#  '(2011–2018)',
#  '(2013–2020)',
#  '(2018– )',
#  '(2006–2021)',
#  '(2015– )',
#  '(1999– )',
#  '(2013– )',
#  '(2004–2010)',
#  '(2013– )',
#  '(2004–2012)',
# ...

# %%
print(len(Year_span))
# Out:
# 100

# %%
genre=driver.find_elements_by_xpath("//span[@class='genre']")
genre
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="38483d049f10acc130e94c1a03dd76a4", element="d8ee78ad-6563-4b40-93d5-66ee217a7fee")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="38483d049f10acc130e94c1a03dd76a4", element="eb049f64-ffdd-48ca-b7ef-585b61970c84")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="38483d049f10acc130e94c1a03dd76a4", element="f0f3f16e-8ed8-4200-802e-94efa3bc7548")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="38483d049f10acc130e94c1a03dd76a4", element="15f1327b-69e5-4804-8b08-c048b9aa969b")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="38483d049f10acc130e94c1a03dd76a4", element="d617018a-dda9-4028-b0e7-4f1d910326ea")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="38483d049f10acc130e94c1a03dd76a4", element="d1d37973-e4ba-4a50-a686-75159ce99848")>,
# ...

# %%
Genre=[]
for i in genre:
    Genre.append(i.text)
Genre
# Out:
# ['Action, Adventure, Drama',
#  'Drama, Fantasy, Horror',
#  'Drama, Horror, Thriller',
#  'Drama, Mystery, Thriller',
#  'Drama, Mystery, Sci-Fi',
#  'Comedy, Crime, Drama',
#  'Crime, Drama, Mystery',
#  'Drama, Romance',
#  'Action, Adventure, Drama',
#  'Action, Adventure, Crime',
#  'Action, Crime, Mystery',
#  'Comedy, Romance',
#  'Drama, Sci-Fi, Thriller',
#  'Crime, Drama, Mystery',
#  'Action, Adventure, Drama',
#  'Drama, Mystery, Romance',
#  'Drama, Fantasy, Horror',
#  'Drama, Horror, Thriller',
#  'Crime, Drama, Thriller',
#  'Crime, Drama, Fantasy',
#  'Drama, Fantasy, Horror',
#  'Action, Crime, Drama',
#  'Crime, Drama, Mystery',
#  'Action, Drama, Fantasy',
#  'Animation, Comedy',
#  'Adventure, Fantasy, Romance',
#  'Biography, Crime, Drama',
#  'Action, Crime, Drama',
#  'Comedy, Romance',
#  'Comedy, Romance',
#  'Comedy, Drama',
#  'Crime, Drama, Thriller',
#  'Drama, Fantasy, Horror',
#  'Action, Adventure, Drama',
#  'Drama, Romance',
# ...

# %%
print(len(Genre))
# Out:
# 100

# %%
runtime=driver.find_elements_by_xpath("//span[@class='runtime']")
runtime
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="38483d049f10acc130e94c1a03dd76a4", element="5d4fd3ea-0be9-4309-b90f-5683794a842a")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="38483d049f10acc130e94c1a03dd76a4", element="23fab4f2-2de8-4f91-ba80-ea5d4b03d0b6")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="38483d049f10acc130e94c1a03dd76a4", element="b0525514-13d2-41bd-a4ad-d8437dca10a5")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="38483d049f10acc130e94c1a03dd76a4", element="4dfa3612-7dd5-4b8d-bad3-5aed58470655")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="38483d049f10acc130e94c1a03dd76a4", element="6402ed31-e8d5-4ced-80bf-3eb13e458189")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="38483d049f10acc130e94c1a03dd76a4", element="35b09029-f5e8-4f03-a704-16acf7394d0a")>,
# ...

# %%
Runtime=[]
for i in runtime:
    Runtime.append(i.text)
Runtime
# Out:
# ['57 min',
#  '51 min',
#  '44 min',
#  '60 min',
#  '43 min',
#  '59 min',
#  '45 min',
#  '41 min',
#  '43 min',
#  '42 min',
#  '70 min',
#  '22 min',
#  '60 min',
#  '88 min',
#  '44 min',
#  '44 min',
#  '43 min',
#  '60 min',
#  '49 min',
#  '42 min',
#  '44 min',
#  '44 min',
#  '43 min',
#  '41 min',
#  '22 min',
#  '60 min',
#  '49 min',
#  '54 min',
#  '22 min',
#  '22 min',
#  '44 min',
#  '49 min',
#  '45 min',
#  '43 min',
#  '42 min',
#  '60 min',
#  '42 min',
#  '62 min',
#  '56 min',
#  '22 min',
#  '23 min',
#  '42 min',
#  '25 min',
#  '51 min',
#  '60 min',
#  '60 min',
#  '45 min',
#  '46 min',
#  '22 min',
#  '45 min',
#  '45 min',
#  '53 min',
#  '44 min',
#  '22 min',
#  '43 min',
#  '44 min',
#  '60 min',
#  '44 min',
#  '42 min',
#  '44 min',
#  '55 min',
#  '42 min',
#  '42 min',
#  '60 min',
#  '60 min',
#  '41 min',
#  '60 min',
#  '44 min',
#  '22 min',
#  '22 min',
#  '43 min',
#  '60 min',
#  '55 min',
#  '60 min',
#  '45 min',
#  '46 min',
# ...

# %%
print(len(Runtime))
# Out:
# 100

# %%
rating=driver.find_elements_by_xpath("//div[@class='ipl-rating-widget']")
rating
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="38483d049f10acc130e94c1a03dd76a4", element="8bcdb97c-a31d-4517-b64a-9557a5dbd5ae")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="38483d049f10acc130e94c1a03dd76a4", element="514c1e7c-4c32-411a-b04c-c2d28edefb89")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="38483d049f10acc130e94c1a03dd76a4", element="a9345181-3958-4cb8-8ae3-907b80cf5704")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="38483d049f10acc130e94c1a03dd76a4", element="56b6dd22-837c-4fc3-9c7d-727f993e4883")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="38483d049f10acc130e94c1a03dd76a4", element="4866ba70-7b34-4aca-a323-433252cee14e")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="38483d049f10acc130e94c1a03dd76a4", element="5a12a151-ba83-4544-b93a-0ba8ce95d227")>,
# ...

# %%
Rating=[]
for i in rating:
    Rating.append(i.text)
Rating
# Out:
# ['9.3\nRate',
#  '8.7\nRate',
#  '8.2\nRate',
#  '7.6\nRate',
#  '7.6\nRate',
#  '8\nRate',
#  '6.8\nRate',
#  '7.5\nRate',
#  '7.6\nRate',
#  '7.5\nRate',
#  '8.3\nRate',
#  '8.1\nRate',
#  '8.8\nRate',
#  '9.1\nRate',
#  '8.5\nRate',
#  '7.4\nRate',
#  '7.7\nRate',
#  '8\nRate',
#  '9.4\nRate',
#  '8.1\nRate',
#  '8.4\nRate',
#  '8.3\nRate',
#  '8.1\nRate',
#  '7.6\nRate',
#  '8.6\nRate',
#  '7.7\nRate',
#  '8.8\nRate',
#  '8.6\nRate',
#  '8.9\nRate',
#  '8.3\nRate',
#  '8.4\nRate',
#  '8.5\nRate',
#  '8.2\nRate',
#  '6.2\nRate',
#  '7.4\nRate',
#  '8.3\nRate',
#  '7.8\nRate',
#  '8.6\nRate',
#  '7.9\nRate',
#  '8.4\nRate',
#  '9.2\nRate',
#  '6.6\nRate',
#  '8.1\nRate',
#  '8.7\nRate',
#  '8.8\nRate',
#  '7.5\nRate',
#  '8.3\nRate',
#  '8.5\nRate',
#  '7.7\nRate',
#  '7.5\nRate',
#  '7.7\nRate',
#  '8.6\nRate',
#  '6.9\nRate',
#  '8.1\nRate',
#  '8\nRate',
#  '8.3\nRate',
#  '8.8\nRate',
#  '8.7\nRate',
#  '6.7\nRate',
#  '8.3\nRate',
#  '8.3\nRate',
#  '7.4\nRate',
# ...

# %%
print(len(Rating))
# Out:
# 100

# %%
votes=driver.find_elements_by_xpath("//span[@name='nv']")
votes
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="38483d049f10acc130e94c1a03dd76a4", element="e9418077-b81f-4cb0-afad-6d93d00174d7")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="38483d049f10acc130e94c1a03dd76a4", element="d4c46ded-75f5-4853-b8b8-3444d1684403")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="38483d049f10acc130e94c1a03dd76a4", element="f7983ca2-720c-4680-b3f0-f40cc7804bc3")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="38483d049f10acc130e94c1a03dd76a4", element="3bd3f96a-f365-4d48-bb20-96c0410a2e16")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="38483d049f10acc130e94c1a03dd76a4", element="64f094ce-e6e8-4f38-b273-cc46800439cb")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="38483d049f10acc130e94c1a03dd76a4", element="38dd573e-a586-4110-b94c-0d8174111ec6")>,
# ...

# %%
Votes=[]
for i in votes:
    Votes.append(i.text)
Votes
# Out:
# ['1,824,365',
#  '864,584',
#  '874,869',
#  '262,809',
#  '224,199',
#  '282,742',
#  '125,124',
#  '261,422',
#  '314,609',
#  '412,418',
#  '331,638',
#  '737,534',
#  '462,692',
#  '830,503',
#  '451,793',
#  '154,740',
#  '290,543',
#  '282,598',
#  '1,527,322',
#  '253,093',
#  '400,032',
#  '487,786',
#  '134,308',
#  '131,135',
#  '372,549',
#  '211,286',
#  '370,868',
#  '371,153',
#  '864,549',
#  '618,222',
#  '371,371',
#  '342,318',
#  '121,164',
#  '114,324',
#  '157,745',
#  '142,827',
#  '214,943',
#  '439,924',
#  '196,438',
#  '371,215',
#  '395,439',
#  '55,413',
#  '154,440',
#  '473,780',
#  '305,483',
#  '53,853',
#  '171,429',
#  '211,116',
#  '198,097',
#  '203,610',
#  '153,788',
#  '658,602',
#  '116,515',
#  '310,156',
#  '207,889',
#  '507,265',
#  '380,605',
#  '422,655',
#  '57,857',
#  '103,467',
#  '320,276',
#  '67,641',
#  '94,485',
#  '187,308',
#  '81,290',
#  '67,723',
#  '40,684',
#  '138,858',
#  '337,463',
#  '242,545',
#  '102,159',
# ...

# %%
print(len(Votes))
# Out:
# 100

# %%
names=driver.find_elements_by_xpath("//h3[@class='lister-item-header']/a")
names
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="38483d049f10acc130e94c1a03dd76a4", element="5b11d036-0b4e-435f-b340-31cffb32cabd")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="38483d049f10acc130e94c1a03dd76a4", element="c814d134-a0dd-4356-9f55-d338f3cf3d60")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="38483d049f10acc130e94c1a03dd76a4", element="18a5a148-a5a6-415c-89d2-77b7659c555c")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="38483d049f10acc130e94c1a03dd76a4", element="fc710d67-91c7-434d-b81f-dafd7bd8fdac")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="38483d049f10acc130e94c1a03dd76a4", element="c2549e79-92a5-40b2-8334-85ebf07019c7")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="38483d049f10acc130e94c1a03dd76a4", element="5648e1dc-de53-41a8-a644-63f8ead7002a")>,
# ...

# %%
Names=[]
for i in names:
    Names.append(i.text)
Names
# Out:
# ['Game of Thrones',
#  'Stranger Things',
#  'The Walking Dead',
#  '13 Reasons Why',
#  'The 100',
#  'Orange Is the New Black',
#  'Riverdale',
#  "Grey's Anatomy",
#  'The Flash',
#  'Arrow',
#  'Money Heist',
#  'The Big Bang Theory',
#  'Black Mirror',
#  'Sherlock',
#  'Vikings',
#  'Pretty Little Liars',
#  'The Vampire Diaries',
#  'American Horror Story',
#  'Breaking Bad',
#  'Lucifer',
#  'Supernatural',
#  'Prison Break',
#  'How to Get Away with Murder',
#  'Teen Wolf',
#  'The Simpsons',
#  'Once Upon a Time',
#  'Narcos',
#  'Daredevil',
#  'Friends',
#  'How I Met Your Mother',
#  'Suits',
#  'Mr. Robot',
#  'The Originals',
#  'Supergirl',
#  'Gossip Girl',
#  'Sense8',
#  'Gotham',
#  'Westworld',
#  'Jessica Jones',
#  'Modern Family',
#  'Rick and Morty',
#  'Shadowhunters',
#  'The End of the F***ing World',
#  'House of Cards',
#  'Dark',
#  'Elite',
#  'Sex Education',
#  'Shameless',
#  'New Girl',
#  'Agents of S.H.I.E.L.D.',
#  'You',
#  'Dexter',
# ...

# %%
print(len(Names))
# Out:
# 100

# %%
Tvshows=pd.DataFrame({})
Tvshows['Names']=Names
Tvshows['Year_span']=Year_span
Tvshows['Genre']=Genre
Tvshows['Runtime']=Runtime
Tvshows['Rating']=Rating
Tvshows['Votes']=Votes

# %%
Tvshows
# Out:
#                              Names    Year_span                     Genre  \
# 0                  Game of Thrones  (2011–2019)  Action, Adventure, Drama
# 1                  Stranger Things     (2016– )    Drama, Fantasy, Horror
# 2                 The Walking Dead  (2010–2022)   Drama, Horror, Thriller
# 3                   13 Reasons Why  (2017–2020)  Drama, Mystery, Thriller
# 4                          The 100  (2014–2020)    Drama, Mystery, Sci-Fi
# ..                             ...          ...                       ...
# 95                           Reign  (2013–2017)            Drama, Fantasy
# 96  A Series of Unfortunate Events  (2017–2019)  Adventure, Comedy, Drama
# 97                  Criminal Minds  (2005–2020)     Crime, Drama, Mystery
# 98           Scream: The TV Series  (2015–2019)      Comedy, Crime, Drama
# 99      The Haunting of Hill House       (2018)    Drama, Horror, Mystery
#
#     Runtime     Rating      Votes
# 0    57 min  9.3\nRate  1,824,365
# ...

# %%
driver.close()

# %% [markdown]
# # ques 10

# %%
driver=webdriver.Chrome(r"C:\Users\DELL\Downloads\chromedriver")
driver.get("https://archive.ics.uci.edu/ml/datasets.php")

# %%
name=[]
try:
    names=driver.find_elements_by_xpath("/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[1]")
    for i in names[:]:
        name.append(i.text)
except NoSuchElementsException:
    name.append('No details found')
print(len(name))
# Out:
# 589

# %%
name
# Out:
# ['Name',
#  '  Abalone',
#  '  Adult',
#  '  Annealing',
#  '  Anonymous Microsoft Web Data',
#  '  Arrhythmia',
#  '  Artificial Characters',
#  '  Audiology (Original)',
#  '  Audiology (Standardized)',
#  '  Auto MPG',
#  '  Automobile',
#  '  Badges',
#  '  Balance Scale',
#  '  Balloons',
#  '  Breast Cancer',
#  '  Breast Cancer Wisconsin (Original)',
#  '  Breast Cancer Wisconsin (Prognostic)',
#  '  Breast Cancer Wisconsin (Diagnostic)',
#  '  Pittsburgh Bridges',
#  '  Car Evaluation',
#  '  Census Income',
#  '  Chess (King-Rook vs. King-Knight)',
#  '  Chess (King-Rook vs. King-Pawn)',
#  '  Chess (King-Rook vs. King)',
#  '  Chess (Domain Theories)',
#  '  Bach Chorales',
#  '  Connect-4',
#  '  Credit Approval',
#  '  Japanese Credit Screening',
#  '  Computer Hardware',
#  '  Contraceptive Method Choice',
#  '  Covertype',
#  '  Cylinder Bands',
#  '  Dermatology',
#  '  Diabetes',
#  '  DGP2 - The Second Data Generation Program',
#  '  Document Understanding',
# ...

# %%
data_type=[]
try:
    data=driver.find_elements_by_xpath("/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[2]")
    for i in data[:]:
        data_type.append(i.text)
except NoSuchElementException:
    data_type.append('No details found')
print(len(data_type))
# Out:
# 589

# %%
data_type
# Out:
# ['Data Types',
#  'Multivariate ',
#  'Multivariate ',
#  'Multivariate ',
#  ' ',
#  'Multivariate ',
#  'Multivariate ',
#  'Multivariate ',
#  'Multivariate ',
#  'Multivariate ',
#  'Multivariate ',
#  'Univariate, Text ',
#  'Multivariate ',
#  'Multivariate ',
#  'Multivariate ',
#  'Multivariate ',
#  'Multivariate ',
#  'Multivariate ',
#  'Multivariate ',
#  'Multivariate ',
#  'Multivariate ',
#  'Multivariate, Data-Generator ',
#  'Multivariate ',
#  'Multivariate ',
#  'Domain-Theory ',
#  'Univariate, Time-Series ',
#  'Multivariate, Spatial ',
#  'Multivariate ',
#  'Multivariate, Domain-Theory ',
#  'Multivariate ',
#  'Multivariate ',
#  'Multivariate ',
#  'Multivariate ',
#  'Multivariate ',
#  'Multivariate, Time-Series ',
#  'Data-Generator ',
#  ' ',
#  ' ',
#  'Multivariate ',
#  'Multivariate ',
#  'Multivariate ',
#  ' ',
#  'Multivariate ',
#  'Multivariate ',
#  'Multivariate ',
#  'Multivariate ',
#  'Multivariate ',
#  'Multivariate ',
# ...

# %%
task=[]
try:
    task_default=driver.find_elements_by_xpath("/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[3]")
    for i in task_default[:]:
        task.append(i.text)
except NoSuchElementException:
    tast.append('No details available')
print(len(task))
# Out:
# 589

# %%
task
# Out:
# ['Default Task',
#  'Classification ',
#  'Classification ',
#  'Classification ',
#  'Recommender-Systems ',
#  'Classification ',
#  'Classification ',
#  'Classification ',
#  'Classification ',
#  'Regression ',
#  'Regression ',
#  'Classification ',
#  'Classification ',
#  'Classification ',
#  'Classification ',
#  'Classification ',
#  'Classification, Regression ',
#  'Classification ',
#  'Classification ',
#  'Classification ',
#  'Classification ',
#  'Classification ',
#  'Classification ',
#  'Classification ',
#  ' ',
#  ' ',
#  'Classification ',
#  'Classification ',
#  'Classification ',
#  'Regression ',
#  'Classification ',
#  'Classification ',
#  'Classification ',
#  'Classification ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  'Classification ',
#  'Classification ',
#  'Classification ',
#  'Function-Learning ',
#  'Classification ',
#  'Classification ',
#  'Classification ',
#  'Classification ',
#  'Classification ',
#  'Classification ',
#  ' ',
# ...

# %%
Attribute=[]
try:
    attribute_type=driver.find_elements_by_xpath("/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[4]")
    for i in attribute_type[:]:
        Attribute.append(i.text)
except NoSuchElementException:
    Attribute.append('No details available')
print(len(Attribute))
# Out:
# 589

# %%
Attribute
# Out:
# ['Attribute Types',
#  'Categorical, Integer, Real ',
#  'Categorical, Integer ',
#  'Categorical, Integer, Real ',
#  'Categorical ',
#  'Categorical, Integer, Real ',
#  'Categorical, Integer, Real ',
#  'Categorical ',
#  'Categorical ',
#  'Categorical, Real ',
#  'Categorical, Integer, Real ',
#  ' ',
#  'Categorical ',
#  'Categorical ',
#  'Categorical ',
#  'Integer ',
#  'Real ',
#  'Real ',
#  'Categorical, Integer ',
#  'Categorical ',
#  'Categorical, Integer ',
#  'Categorical, Integer ',
#  'Categorical ',
#  'Categorical, Integer ',
#  ' ',
#  'Categorical, Integer ',
#  'Categorical ',
#  'Categorical, Integer, Real ',
#  'Categorical, Real, Integer ',
#  'Integer ',
#  'Categorical, Integer ',
#  'Categorical, Integer ',
#  'Categorical, Integer, Real ',
#  'Categorical, Integer ',
#  'Categorical, Integer ',
#  'Real ',
#  ' ',
#  ' ',
#  'Categorical, Integer, Real ',
#  'Real ',
#  'Categorical, Integer ',
#  'Real ',
#  'Real ',
#  'Integer ',
#  'Categorical ',
# ...

# %%
Instance=[]
try:
    instance=driver.find_elements_by_xpath("/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[5]")
    for i in instance[:]:
        Instance.append(i.text)
except NoSuchElementException:
    Instance.append('No deatils available')
print(len(Instance))
# Out:
# 589

# %%
Instance
# Out:
# ['# Instances',
#  '4177 ',
#  '48842 ',
#  '798 ',
#  '37711 ',
#  '452 ',
#  '6000 ',
#  '226 ',
#  '226 ',
#  '398 ',
#  '205 ',
#  '294 ',
#  '625 ',
#  '16 ',
#  '286 ',
#  '699 ',
#  '198 ',
#  '569 ',
#  '108 ',
#  '1728 ',
#  '48842 ',
#  ' ',
#  '3196 ',
#  '28056 ',
#  ' ',
#  '100 ',
#  '67557 ',
#  '690 ',
#  '125 ',
#  '209 ',
#  '1473 ',
#  '581012 ',
#  '512 ',
#  '366 ',
#  ' ',
#  ' ',
#  ' ',
#  ' ',
#  '132 ',
#  '336 ',
#  '194 ',
#  '352 ',
#  '214 ',
#  '306 ',
#  '160 ',
#  '303 ',
#  '155 ',
#  '368 ',
#  ' ',
#  '2310 ',
#  '3279 ',
#  '351 ',
#  '150 ',
#  '7797 ',
#  '104 ',
#  '57 ',
#  ' ',
#  '24 ',
#  '20000 ',
#  '345 ',
#  ' ',
#  '32 ',
#  '148 ',
#  '209 ',
#  '528 ',
#  ' ',
#  '106 ',
#  '128 ',
#  '3190 ',
#  '432 ',
#  '202 ',
#  '2000 ',
#  '8124 ',
#  '476 ',
#  '6598 ',
#  '12960 ',
#  ' ',
#  '5473 ',
#  '5620 ',
#  '10992 ',
#  '90 ',
#  '339 ',
#  ' ',
#  ' ',
#  ' ',
#  '167 ',
#  '15 ',
#  '1389 ',
#  '307 ',
#  '47 ',
#  '23 ',
# ...

# %%
No_of_attribute=[]
try:
    NOA=driver.find_elements_by_xpath("/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[6]")
    for i in NOA[:]:
        No_of_attribute.append(i.text)
except NoSuchElementException:
    No_of_attribute.append('No details available')
print(len(No_of_attribute))
# Out:
# 589

# %%
No_of_attribute
# Out:
# ['# Attributes',
#  '8 ',
#  '14 ',
#  '38 ',
#  '294 ',
#  '279 ',
#  '7 ',
#  ' ',
#  '69 ',
#  '8 ',
#  '26 ',
#  '1 ',
#  '4 ',
#  '4 ',
#  '9 ',
#  '10 ',
#  '34 ',
#  '32 ',
#  '13 ',
#  '6 ',
#  '14 ',
#  '22 ',
#  '36 ',
#  '6 ',
#  ' ',
#  '6 ',
#  '42 ',
#  '15 ',
#  ' ',
#  '9 ',
#  '9 ',
#  '54 ',
#  '39 ',
#  '33 ',
#  '20 ',
#  ' ',
#  ' ',
#  ' ',
#  '12 ',
#  '8 ',
#  '30 ',
#  ' ',
#  '10 ',
#  '3 ',
#  '5 ',
#  '75 ',
#  '19 ',
#  '27 ',
#  ' ',
#  '19 ',
#  '1558 ',
#  '34 ',
#  '4 ',
#  '617 ',
#  '12 ',
#  '16 ',
#  '7 ',
#  '4 ',
#  '16 ',
#  '7 ',
#  ' ',
#  '56 ',
#  '18 ',
#  '8 ',
#  '22 ',
#  ' ',
#  '58 ',
#  ' ',
#  '61 ',
#  '7 ',
#  ' ',
#  '649 ',
#  '22 ',
#  '168 ',
#  '168 ',
#  '8 ',
#  ' ',
#  '10 ',
#  '64 ',
#  '16 ',
#  '8 ',
#  '17 ',
#  ' ',
#  ' ',
#  '72 ',
#  '4 ',
#  '6 ',
#  '10 ',
#  '35 ',
#  '35 ',
#  '4 ',
#  '102 ',
#  '57 ',
#  '22 ',
#  '44 ',
#  '45 ',
#  ' ',
#  ' ',
#  '5 ',
#  '9 ',
#  '21 ',
#  '32 ',
#  '17 ',
#  '16 ',
# ...

# %%
Year=[]
try:
    year=driver.find_elements_by_xpath("/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[7]")
    for i in year[:]:
        Year.append(i.text)
except NoSuchelementException:
    Year.append('No detailsavailable')
print(len(Year))
# Out:
# 589

# %%
Year
# Out:
# ['Year',
#  '1995 ',
#  '1996 ',
#  ' ',
#  '1998 ',
#  '1998 ',
#  '1992 ',
#  '1987 ',
#  '1992 ',
#  '1993 ',
#  '1987 ',
#  '1994 ',
#  '1994 ',
#  ' ',
#  '1988 ',
#  '1992 ',
#  '1995 ',
#  '1995 ',
#  '1990 ',
#  '1997 ',
#  '1996 ',
#  '1988 ',
#  '1989 ',
#  '1994 ',
#  ' ',
#  ' ',
#  '1995 ',
#  ' ',
#  '1992 ',
#  '1987 ',
#  '1997 ',
#  '1998 ',
#  '1995 ',
#  '1998 ',
#  ' ',
#  ' ',
#  '1994 ',
#  ' ',
#  '1989 ',
#  '1996 ',
#  '1990 ',
#  '1990 ',
#  '1987 ',
#  '1999 ',
#  '1989 ',
#  '1988 ',
#  '1988 ',
#  '1989 ',
#  ' ',
#  '1990 ',
#  '1998 ',
#  '1989 ',
#  '1988 ',
#  '1994 ',
#  '1990 ',
#  '1988 ',
#  '1988 ',
#  '1990 ',
#  '1991 ',
#  '1990 ',
#  ' ',
#  '1992 ',
#  '1988 ',
#  '1990 ',
#  '1996 ',
#  '1995 ',
#  '1990 ',
#  ' ',
#  '1992 ',
#  '1992 ',
#  '1994 ',
#  ' ',
#  '1987 ',
#  '1994 ',
#  '1994 ',
#  '1997 ',
#  '1991 ',
#  '1995 ',
#  '1998 ',
#  '1998 ',
#  '1993 ',
#  '1988 ',
#  ' ',
#  ' ',
#  '1992 ',
#  '1993 ',
#  '1988 ',
#  '1989 ',
# ...

# %%
Dataset=pd.DataFrame({})
Dataset['Name']=name
Dataset['Data_Type']=data_type
Dataset['Task']=task
Dataset['Attribute']=Attribute
Dataset['Instance']=Instance
Dataset['No_of_attribute']=No_of_attribute
Dataset['Year']=Year

# %%
Dataset
# Out:
#                                    Name      Data_Type                  Task  \
# 0                                  Name     Data Types          Default Task
# 1                               Abalone  Multivariate        Classification
# 2                                 Adult  Multivariate        Classification
# 3                             Annealing  Multivariate        Classification
# 4          Anonymous Microsoft Web Data                 Recommender-Systems
# ..                                  ...            ...                   ...
# 584    in-vehicle coupon recommendation  Multivariate        Classification
# 585                 Gait Classification  Multivariate        Classification
# 586           Wikipedia Math Essentials   Time-Series            Regression
# 587           Wikipedia Math Essentials   Time-Series            Regression
# 588        Synchronous Machine Data Set  Multivariate            Regression
#
# ...

# %%
driver.close()
