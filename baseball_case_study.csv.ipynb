# %%
import numpy as np
import pandas as pd
import sklearn
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split

# %%
ds=pd.read_csv('baseball_case.csv')

# %%
ds
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 0    95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2
# 1    83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2
# 2    81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11
# 3    76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7
# 4    74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7
# 5    93  891  5509  1480  308  17  232  570  1151   88  670  609  3.80   7
# 6    87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3
# 7    81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0
# 8    80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1
# 9    78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3
# 10   88  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5
# ...

# %%
ds.keys()
# Out:
# Index(['W', 'R', 'AB', 'H', '2B', '3B', 'HR', 'BB', 'SO', 'SB', 'RA', 'ER',
#        'ERA', 'CG', 'SHO', 'SV', 'E'],
#       dtype='object')

# %%
ds
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 0    95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2
# 1    83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2
# 2    81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11
# 3    76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7
# 4    74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7
# 5    93  891  5509  1480  308  17  232  570  1151   88  670  609  3.80   7
# 6    87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3
# 7    81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0
# 8    80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1
# 9    78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3
# 10   88  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5
# ...

# %%
ds.shape
# Out:
# (30, 17)

# %%
ds.dtypes
# Out:
# W        int64
# R        int64
# AB       int64
# H        int64
# 2B       int64
# 3B       int64
# HR       int64
# BB       int64
# SO       int64
# SB       int64
# RA       int64
# ER       int64
# ERA    float64
# CG       int64
# SHO      int64
# SV       int64
# E        int64
# dtype: object

# %%
ds.isnull().sum()
# Out:
# W      0
# R      0
# AB     0
# H      0
# 2B     0
# 3B     0
# HR     0
# BB     0
# SO     0
# SB     0
# RA     0
# ER     0
# ERA    0
# CG     0
# SHO    0
# SV     0
# E      0
# dtype: int64

# %%
sns.heatmap(ds.isnull())
# Out:
# <AxesSubplot:>

# %%
ds.describe()
# Out:
#                 W           R           AB            H          2B  \
# count   30.000000   30.000000    30.000000    30.000000   30.000000
# mean    80.966667  688.233333  5516.266667  1403.533333  274.733333
# std     10.453455   58.761754    70.467372    57.140923   18.095405
# min     63.000000  573.000000  5385.000000  1324.000000  236.000000
# 25%     74.000000  651.250000  5464.000000  1363.000000  262.250000
# 50%     81.000000  689.000000  5510.000000  1382.500000  275.500000
# 75%     87.750000  718.250000  5570.000000  1451.500000  288.750000
# max    100.000000  891.000000  5649.000000  1515.000000  308.000000
#
#               3B          HR          BB          SO          SB          RA  \
# count  30.000000   30.000000   30.000000    30.00000   30.000000   30.000000
# mean   31.300000  163.633333  469.100000  1248.20000   83.500000  688.233333
# std    10.452355   31.823309   57.053725   103.75947   22.815225   72.108005
# ...

# %%
#skewness is very rare so we dont need to remove it 
ds.skew()
# Out:
# W      0.047089
# R      1.200786
# AB     0.183437
# H      0.670254
# 2B    -0.230650
# 3B     0.129502
# HR     0.516441
# BB     0.158498
# SO    -0.156065
# SB     0.479893
# RA     0.045734
# ER     0.058710
# ERA    0.053331
# CG     0.736845
# SHO    0.565790
# SV     0.657524
# E      0.890132
# dtype: float64

# %%
ds['BB'].plot(kind='box')
# Out:
# <AxesSubplot:>

# %%
ds['R'].plot(kind='box')
# Out:
# <AxesSubplot:>

# %%
ds['SO'].plot(kind='box')
# Out:
# <AxesSubplot:>

# %%
ds['CG'].plot(kind='box')
# Out:
# <AxesSubplot:>

# %%
 ds.plot(kind='box',subplots=True)
# Out:
# W         AxesSubplot(0.125,0.125;0.0383663x0.755)
# R       AxesSubplot(0.17104,0.125;0.0383663x0.755)
# AB     AxesSubplot(0.217079,0.125;0.0383663x0.755)
# H      AxesSubplot(0.263119,0.125;0.0383663x0.755)
# 2B     AxesSubplot(0.309158,0.125;0.0383663x0.755)
# 3B     AxesSubplot(0.355198,0.125;0.0383663x0.755)
# HR     AxesSubplot(0.401238,0.125;0.0383663x0.755)
# BB     AxesSubplot(0.447277,0.125;0.0383663x0.755)
# SO     AxesSubplot(0.493317,0.125;0.0383663x0.755)
# SB     AxesSubplot(0.539356,0.125;0.0383663x0.755)
# RA     AxesSubplot(0.585396,0.125;0.0383663x0.755)
# ER     AxesSubplot(0.631436,0.125;0.0383663x0.755)
# ERA    AxesSubplot(0.677475,0.125;0.0383663x0.755)
# CG     AxesSubplot(0.723515,0.125;0.0383663x0.755)
# SHO    AxesSubplot(0.769554,0.125;0.0383663x0.755)
# SV     AxesSubplot(0.815594,0.125;0.0383663x0.755)
# E      AxesSubplot(0.861634,0.125;0.0383663x0.755)
# dtype: object

# %%
ds['SHO'].plot(kind='box')
# Out:
# <AxesSubplot:>

# %%
#there are very less outliers so there is not compulsory to remove the outliaers

# %%
plt.scatter(ds['R'],ds['W'])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#this show that there is negative relationship betweem ERA and W
plt.scatter(ds['ERA'],ds['W'])
plt.show()

# %%
x=ds['SV']
y=ds['W']
plt.scatter(x,y)
plt.show()

# %%
dfcor=ds.corr()
dfcor
# Out:
#             W         R        AB         H        2B        3B        HR  \
# W    1.000000  0.430751 -0.087947  0.037612  0.427797 -0.251118  0.307407
# R    0.430751  1.000000  0.319464  0.482856  0.560084 -0.070072  0.671283
# AB  -0.087947  0.319464  1.000000  0.739122  0.453370  0.435422 -0.066983
# H    0.037612  0.482856  0.739122  1.000000  0.566847  0.478694 -0.090855
# 2B   0.427797  0.560084  0.453370  0.566847  1.000000  0.220490  0.056292
# 3B  -0.251118 -0.070072  0.435422  0.478694  0.220490  1.000000 -0.430915
# HR   0.307407  0.671283 -0.066983 -0.090855  0.056292 -0.430915  1.000000
# BB   0.484342  0.402452 -0.136414 -0.118281  0.302700 -0.454949  0.425691
# SO   0.111850 -0.054726 -0.106022 -0.398830 -0.150752 -0.141196  0.359923
# SB  -0.157234  0.081367  0.372618  0.413444  0.195027  0.457437 -0.136567
# RA  -0.812952 -0.041623  0.316010  0.224324 -0.218160  0.314125 -0.103903
# ER  -0.809435 -0.041245  0.309686  0.252489 -0.235531  0.340225 -0.085922
# ...

# %%
fig=plt.figure(figsize=(10,5))
hc=ds.corr(method='pearson')
sns.heatmap(hc,annot=True,cmap="Blues")
# Out:
# <AxesSubplot:>

# %%
plt.scatter(ds['W'],ds['2B'])

# %%
plt.scatter(ds['W'],ds['AB'])
plt.show()

# %%
x=ds.iloc[:,1:17]

# %%
x
# Out:
#       R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  SHO  \
# 0   724  5575  1497  300  42  139  383   973  104  641  601  3.73   2    8
# 1   696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2   12
# 2   669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11   10
# 3   622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7    9
# 4   689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7   12
# 5   891  5509  1480  308  17  232  570  1151   88  670  609  3.80   7   10
# 6   764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3    4
# 7   713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0   10
# 8   644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1   12
# 9   748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3   10
# 10  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5    9
# ...

# %%
y=ds.iloc[:,0]

# %%
y
# Out:
# 0      95
# 1      83
# 2      81
# 3      76
# 4      74
# 5      93
# 6      87
# 7      81
# 8      80
# 9      78
# 10     88
# 11     86
# 12     85
# 13     76
# 14     68
# 15    100
# 16     98
# 17     97
# 18     68
# 19     64
# 20     90
# 21     83
# 22     71
# 23     67
# 24     63
# 25     92
# 26     84
# 27     79
# 28     74
# 29     68
# Name: W, dtype: int64

# %%
x.shape
# Out:
# (30, 16)

# %%
y.shape
# Out:
# (30,)

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.33,random_state=42)

# %%
x_train.shape
# Out:
# (20, 16)

# %%
y_train.shape
# Out:
# (20,)

# %%
x_test.shape
# Out:
# (10, 16)

# %%
y_test.shape
# Out:
# (10,)

# %%
lm=LinearRegression()

# %%
lm.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
lm.coef_
# Out:
# array([ 0.11407665, -0.00130833,  0.00216518, -0.15095867,  0.14133276,
#        -0.01147221, -0.0300024 , -0.01038731,  0.04369688,  0.34690705,
#        -0.40672858, -1.25582776,  1.01015855,  0.31133373,  1.24412837,
#        -0.11513656])

# %%
lm.intercept_
# Out:
# 45.46381631241603

# %%
lm.score(x_train,y_train)
# Out:
# 0.9852165036614605

# %%
#predict the values
pred=lm.predict(x_test)
print("predicted result price:",pred)
print("actual price:",y_test)
# Out:
# predicted result price: [ 86.09500664 106.01562859  72.31452739  96.53454698  93.31028336
#   80.20238221  81.84014348  57.67641007  83.45864565 103.2925551 ]
# actual price: 27     79
# 15    100
# 23     67
# 17     97
# 8      80
# 9      78
# 28     74
# 24     63
# 12     85
# 0      95
# Name: W, dtype: int64

# %%
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error

# %%
print('error:')
print('Mean absolute error:',mean_absolute_error(y_test,pred))
print('Mean squared error:',y_test,pred)
# Out:
# error:
# Mean absolute error: 5.740092406895946
# Mean squared error: 27     79
# 15    100
# 23     67
# 17     97
# 8      80
# 9      78
# 28     74
# 24     63
# 12     85
# 0      95
# Name: W, dtype: int64 [ 86.09500664 106.01562859  72.31452739  96.53454698  93.31028336
#   80.20238221  81.84014348  57.67641007  83.45864565 103.2925551 ]

# %%
#r2score--->coeficient of determination
from sklearn.metrics import r2_score

# %%
print(r2_score(y_test,pred))
# Out:
# 0.6741942317769304

# %%
from sklearn.linear_model import Lasso,Ridge

# %%
ls=Lasso(alpha=0.0001)
ls.fit(x_train,y_train)
ls.score(x_train,y_train)
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 13.097887264362209, tolerance: 0.17529500000000003
#   model = cd_fast.enet_coordinate_descent(
# 0.9850606129187672

# %%
ls.coef_
# Out:
# array([ 1.13169861e-01, -6.70465562e-03,  5.29871642e-03, -1.41796409e-01,
#         1.45092390e-01, -1.28550802e-02, -2.85228715e-02, -9.07052197e-03,
#         3.61192094e-02,  3.10412102e-01, -3.02862700e-01, -1.21244197e+01,
#         9.53422066e-01,  2.69868874e-01,  1.17700213e+00, -1.05439812e-01])

# %%
rd=Ridge(alpha=0.0001)
rd.fit(x_train,y_train)
rd.score(x_train,y_train)
# Out:
# 0.9852164994856739

# %%
rd.coef_
# Out:
# array([ 0.11407924, -0.00127728,  0.00214857, -0.1509939 ,  0.14129154,
#        -0.01146915, -0.03000668, -0.01039201,  0.04373169,  0.34704352,
#        -0.40725069, -1.19368758,  1.01041534,  0.31154655,  1.24443808,
#        -0.11517106])

# %%
import joblib
joblib.dump(rd,"rdmodel.obj")
# Out:
# ['rdmodel.obj']
